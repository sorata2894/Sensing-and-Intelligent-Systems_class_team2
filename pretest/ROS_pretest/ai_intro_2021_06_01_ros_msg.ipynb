# %% [markdown]
# # ROS Messages

# %% [markdown]
# ## Setup
#
# This will take a couple minutes

# %%
#@title Install ROS {display-mode: "form"}
# !sudo sh -c 'echo "deb http://packages.ros.org/ros/ubuntu $(lsb_release -sc) main" > /etc/apt/sources.list.d/ros-latest.list'
# !sudo apt-key adv --keyserver 'hkp://keyserver.ubuntu.com:80' --recv-key C1CF6E31E6BADE8868B172B4F42ED6FBAB17C654
# !sudo apt update
# !sudo apt install ros-melodic-ros-base
# Out:
# Executing: /tmp/apt-key-gpghome.eE4NpFZea2/gpg.1.sh --keyserver hkp://keyserver.ubuntu.com:80 --recv-key C1CF6E31E6BADE8868B172B4F42ED6FBAB17C654
# gpg: key F42ED6FBAB17C654: public key "Open Robotics <info@osrfoundation.org>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://packages.ros.org/ros/ubuntu bionic InRelease [4,680 B]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:12 http://packages.ros.org/ros/ubuntu bionic/main amd64 Packages [783 kB]
# Hit:14 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:15 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:16 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:17 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:18 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [930 kB]
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,827 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,596 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,252 kB]
# Get:22 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,474 kB]
# Get:23 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [806 kB]
# Get:24 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [937 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [840 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,035 kB]
# Get:27 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [42.8 kB]
# Fetched 15.8 MB in 5s (2,986 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 67 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-470
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   binfmt-support docutils-common docutils-doc google-mock googletest libapr1
#   libapr1-dev libaprutil1 libaprutil1-dev libassuan-dev libconsole-bridge-dev
#   libconsole-bridge0.4 libgpgme-dev libgpgme11 libgtest-dev libldap-2.4-2
#   libldap-common libldap2-dev liblog4cxx-dev liblog4cxx10v5 liblz4-1
#   liblz4-dev libnotify4 libpoco-dev libpococrypto50 libpocodata50
#   libpocodatamysql50 libpocodataodbc50 libpocodatasqlite50 libpocofoundation50
#   libpocojson50 libpocomongodb50 libpoconet50 libpoconetssl50 libpocoredis50
#   libpocoutil50 libpocoxml50 libpocozip50 libsctp-dev libsctp1 libtinyxml2-6
#   libtinyxml2-dev libwxbase3.0-0v5 libwxgtk3.0-gtk3-0v5 notification-daemon
#   python-asn1crypto python-catkin-pkg python-catkin-pkg-modules
#   python-cffi-backend python-chardet python-cryptography python-dateutil
#   python-defusedxml python-docutils python-empy python-enum34 python-gnupg
#   python-idna python-ipaddress python-netifaces python-nose python-olefile
#   python-paramiko python-pil python-pkg-resources python-pyasn1
#   python-pycryptodome python-pygments python-pyparsing python-roman
#   python-rosdep-modules python-rosdistro python-rosdistro-modules
#   python-rospkg python-rospkg-modules python-setuptools python-six
#   python-wxgtk3.0 python-wxtools python-wxversion python-yaml
#   ros-melodic-actionlib ros-melodic-actionlib-msgs ros-melodic-bond
#   ros-melodic-bond-core ros-melodic-bondcpp ros-melodic-bondpy
#   ros-melodic-catkin ros-melodic-class-loader ros-melodic-cmake-modules
#   ros-melodic-common-msgs ros-melodic-cpp-common ros-melodic-diagnostic-msgs
#   ros-melodic-dynamic-reconfigure ros-melodic-gencpp ros-melodic-geneus
#   ros-melodic-genlisp ros-melodic-genmsg ros-melodic-gennodejs
#   ros-melodic-genpy ros-melodic-geometry-msgs ros-melodic-message-filters
#   ros-melodic-message-generation ros-melodic-message-runtime ros-melodic-mk
#   ros-melodic-nav-msgs ros-melodic-nodelet ros-melodic-nodelet-core
#   ros-melodic-nodelet-topic-tools ros-melodic-pluginlib ros-melodic-ros
#   ros-melodic-ros-comm ros-melodic-ros-core ros-melodic-ros-environment
#   ros-melodic-rosbag ros-melodic-rosbag-migration-rule
#   ros-melodic-rosbag-storage ros-melodic-rosbash ros-melodic-rosboost-cfg
#   ros-melodic-rosbuild ros-melodic-rosclean ros-melodic-rosconsole
#   ros-melodic-rosconsole-bridge ros-melodic-roscpp ros-melodic-roscpp-core
#   ros-melodic-roscpp-serialization ros-melodic-roscpp-traits
#   ros-melodic-roscreate ros-melodic-rosgraph ros-melodic-rosgraph-msgs
#   ros-melodic-roslang ros-melodic-roslaunch ros-melodic-roslib
#   ros-melodic-roslisp ros-melodic-roslz4 ros-melodic-rosmake
#   ros-melodic-rosmaster ros-melodic-rosmsg ros-melodic-rosnode
#   ros-melodic-rosout ros-melodic-rospack ros-melodic-rosparam
#   ros-melodic-rospy ros-melodic-rosservice ros-melodic-rostest
#   ros-melodic-rostime ros-melodic-rostopic ros-melodic-rosunit
#   ros-melodic-roswtf ros-melodic-sensor-msgs ros-melodic-shape-msgs
#   ros-melodic-smclib ros-melodic-std-msgs ros-melodic-std-srvs
#   ros-melodic-stereo-msgs ros-melodic-topic-tools ros-melodic-trajectory-msgs
#   ros-melodic-visualization-msgs ros-melodic-xmlrpcpp sbcl sgml-base xml-core
# Suggested packages:
#   liblog4cxx-doc lksctp-tools python-cryptography-doc
#   python-cryptography-vectors fonts-linuxlibertine | ttf-linux-libertine
#   texlive-lang-french texlive-latex-base texlive-latex-recommended
#   python-enum34-doc python-coverage python-nose-doc python-gssapi
#   python-pil-doc python-pil-dbg ttf-bitstream-vera python-pyparsing-doc
#   python-setuptools-doc wx3.0-doc sbcl-doc sbcl-source slime sgml-base-doc
#   debhelper
# The following NEW packages will be installed:
#   binfmt-support docutils-common docutils-doc google-mock googletest libapr1
#   libapr1-dev libaprutil1 libaprutil1-dev libassuan-dev libconsole-bridge-dev
#   libconsole-bridge0.4 libgpgme-dev libgpgme11 libgtest-dev libldap2-dev
#   liblog4cxx-dev liblog4cxx10v5 liblz4-dev libnotify4 libpoco-dev
#   libpococrypto50 libpocodata50 libpocodatamysql50 libpocodataodbc50
#   libpocodatasqlite50 libpocofoundation50 libpocojson50 libpocomongodb50
#   libpoconet50 libpoconetssl50 libpocoredis50 libpocoutil50 libpocoxml50
#   libpocozip50 libsctp-dev libsctp1 libtinyxml2-6 libtinyxml2-dev
#   libwxbase3.0-0v5 libwxgtk3.0-gtk3-0v5 notification-daemon python-asn1crypto
#   python-catkin-pkg python-catkin-pkg-modules python-cffi-backend
#   python-chardet python-cryptography python-dateutil python-defusedxml
#   python-docutils python-empy python-enum34 python-gnupg python-idna
#   python-ipaddress python-netifaces python-nose python-olefile python-paramiko
#   python-pil python-pkg-resources python-pyasn1 python-pycryptodome
#   python-pygments python-pyparsing python-roman python-rosdep-modules
#   python-rosdistro python-rosdistro-modules python-rospkg
#   python-rospkg-modules python-setuptools python-six python-wxgtk3.0
#   python-wxtools python-wxversion python-yaml ros-melodic-actionlib
#   ros-melodic-actionlib-msgs ros-melodic-bond ros-melodic-bond-core
#   ros-melodic-bondcpp ros-melodic-bondpy ros-melodic-catkin
#   ros-melodic-class-loader ros-melodic-cmake-modules ros-melodic-common-msgs
#   ros-melodic-cpp-common ros-melodic-diagnostic-msgs
#   ros-melodic-dynamic-reconfigure ros-melodic-gencpp ros-melodic-geneus
#   ros-melodic-genlisp ros-melodic-genmsg ros-melodic-gennodejs
#   ros-melodic-genpy ros-melodic-geometry-msgs ros-melodic-message-filters
#   ros-melodic-message-generation ros-melodic-message-runtime ros-melodic-mk
#   ros-melodic-nav-msgs ros-melodic-nodelet ros-melodic-nodelet-core
#   ros-melodic-nodelet-topic-tools ros-melodic-pluginlib ros-melodic-ros
#   ros-melodic-ros-base ros-melodic-ros-comm ros-melodic-ros-core
#   ros-melodic-ros-environment ros-melodic-rosbag
#   ros-melodic-rosbag-migration-rule ros-melodic-rosbag-storage
#   ros-melodic-rosbash ros-melodic-rosboost-cfg ros-melodic-rosbuild
#   ros-melodic-rosclean ros-melodic-rosconsole ros-melodic-rosconsole-bridge
#   ros-melodic-roscpp ros-melodic-roscpp-core ros-melodic-roscpp-serialization
#   ros-melodic-roscpp-traits ros-melodic-roscreate ros-melodic-rosgraph
#   ros-melodic-rosgraph-msgs ros-melodic-roslang ros-melodic-roslaunch
#   ros-melodic-roslib ros-melodic-roslisp ros-melodic-roslz4
#   ros-melodic-rosmake ros-melodic-rosmaster ros-melodic-rosmsg
#   ros-melodic-rosnode ros-melodic-rosout ros-melodic-rospack
#   ros-melodic-rosparam ros-melodic-rospy ros-melodic-rosservice
#   ros-melodic-rostest ros-melodic-rostime ros-melodic-rostopic
#   ros-melodic-rosunit ros-melodic-roswtf ros-melodic-sensor-msgs
#   ros-melodic-shape-msgs ros-melodic-smclib ros-melodic-std-msgs
#   ros-melodic-std-srvs ros-melodic-stereo-msgs ros-melodic-topic-tools
#   ros-melodic-trajectory-msgs ros-melodic-visualization-msgs
#   ros-melodic-xmlrpcpp sbcl sgml-base xml-core
# The following packages will be upgraded:
#   libldap-2.4-2 libldap-common liblz4-1
# 3 upgraded, 160 newly installed, 0 to remove and 64 not upgraded.
# Need to get 38.9 MB of archives.
# After this operation, 210 MB of additional disk space will be used.
# Get:1 http://packages.ros.org/ros/ubuntu bionic/main amd64 python-catkin-pkg-modules all 0.4.24-1 [42.3 kB]
# Get:2 http://packages.ros.org/ros/ubuntu bionic/main amd64 python-catkin-pkg all 0.4.24-100 [3,532 B]
# Get:3 http://packages.ros.org/ros/ubuntu bionic/main amd64 python-rospkg-modules all 1.4.0-1 [24.0 kB]
# Get:4 http://packages.ros.org/ros/ubuntu bionic/main amd64 python-rosdistro-modules all 0.8.3-1 [31.8 kB]
# Get:5 http://packages.ros.org/ros/ubuntu bionic/main amd64 python-rosdistro all 0.8.3-100 [6,240 B]
# Get:6 http://packages.ros.org/ros/ubuntu bionic/main amd64 python-rospkg all 1.4.0-100 [2,172 B]
# Get:7 http://packages.ros.org/ros/ubuntu bionic/main amd64 python-rosdep-modules all 0.21.0-1 [51.5 kB]
# Get:8 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-catkin amd64 0.7.29-1bionic.20201014.191449 [128 kB]
# Get:9 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-genmsg amd64 0.5.16-1bionic.20201017.031430 [35.6 kB]
# Get:10 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-gencpp amd64 0.6.5-1bionic.20201017.032453 [15.3 kB]
# Get:11 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-geneus amd64 2.2.6-0bionic.20201017.032432 [25.1 kB]
# Get:12 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-genlisp amd64 0.4.16-0bionic.20201017.032516 [21.8 kB]
# Get:13 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-gennodejs amd64 2.0.1-0bionic.20201017.032446 [21.8 kB]
# Get:14 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-genpy amd64 0.6.16-1bionic.20210505.005001 [52.2 kB]
# Get:15 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-message-generation amd64 0.4.1-1bionic.20210505.005154 [4,768 B]
# Get:16 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-cpp-common amd64 0.6.14-1bionic.20200801.035855 [22.0 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 sgml-base all 1.29 [12.3 kB]
# Get:18 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rostime amd64 0.6.14-1bionic.20200801.051100 [38.9 kB]
# Get:19 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-roscpp-traits amd64 0.6.14-1bionic.20200801.063118 [10.3 kB]
# Get:20 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-roscpp-serialization amd64 0.6.14-1bionic.20200801.063506 [13.1 kB]
# Get:21 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-message-runtime amd64 0.4.12-0bionic.20210505.005252 [4,796 B]
# Get:22 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-std-msgs amd64 0.5.12-0bionic.20210505.005906 [56.4 kB]
# Get:23 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-actionlib-msgs amd64 1.12.8-1bionic.20210505.010611 [26.6 kB]
# Get:24 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosbuild amd64 1.14.9-1bionic.20210505.005821 [27.9 kB]
# Get:25 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosconsole amd64 1.13.18-1bionic.20210505.012210 [86.6 kB]
# Get:26 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosgraph-msgs amd64 1.11.2-0bionic.20210505.012040 [25.3 kB]
# Get:27 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-xmlrpcpp amd64 1.14.12-1bionic.20210921.180110 [59.8 kB]
# Get:28 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-roscpp amd64 1.14.12-1bionic.20210921.180348 [493 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 liblz4-1 amd64 0.0~r131-2ubuntu3.1 [48.5 kB]
# Get:30 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-ros-environment amd64 1.2.3-1bionic.20201015.052244 [5,652 B]
# Get:31 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rospack amd64 2.5.6-1bionic.20201015.070131 [98.8 kB]
# Get:32 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-roslib amd64 1.14.9-1bionic.20201016.105810 [92.2 kB]
# Get:33 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosgraph amd64 1.14.12-1bionic.20210921.180103 [48.1 kB]
# Get:34 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rospy amd64 1.14.12-1bionic.20210921.181015 [134 kB]
# Get:35 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosclean amd64 1.14.9-1bionic.20201015.071027 [11.8 kB]
# Get:36 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosmaster amd64 1.14.12-1bionic.20210921.180319 [41.2 kB]
# Get:37 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosout amd64 1.14.12-1bionic.20210921.202545 [34.0 kB]
# Get:38 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosparam amd64 1.14.12-1bionic.20210921.180319 [17.6 kB]
# Get:39 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosunit amd64 1.14.9-1bionic.20201017.031507 [46.9 kB]
# Get:40 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-roslaunch amd64 1.14.12-1bionic.20210921.202835 [136 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 binfmt-support amd64 2.1.8-2 [51.6 kB]
# Get:42 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rostest amd64 1.14.12-1bionic.20210921.203603 [30.7 kB]
# Get:43 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-class-loader amd64 0.4.1-0bionic.20201015.033003 [61.5 kB]
# Get:44 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-pluginlib amd64 1.12.1-0bionic.20210505.012832 [20.7 kB]
# Get:45 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-roslz4 amd64 1.14.12-1bionic.20210921.180139 [16.4 kB]
# Get:46 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosbag-storage amd64 1.14.12-1bionic.20210921.203950 [178 kB]
# Get:47 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-std-srvs amd64 1.11.2-0bionic.20210505.005914 [18.5 kB]
# Get:48 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-topic-tools amd64 1.14.12-1bionic.20210921.204541 [143 kB]
# Get:49 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosbag amd64 1.14.12-1bionic.20210921.204714 [344 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 xml-core all 0.18 [21.3 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic/main amd64 docutils-common all 0.14+dfsg-3 [156 kB]
# Get:52 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rostopic amd64 1.14.12-1bionic.20210921.205048 [45.0 kB]
# Get:53 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-actionlib amd64 1.12.1-1bionic.20210921.205646 [143 kB]
# Get:54 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-bond amd64 1.8.5-1bionic.20210505.010840 [18.4 kB]
# Get:55 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-smclib amd64 1.8.5-1bionic.20200801.035835 [13.6 kB]
# Get:56 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-bondcpp amd64 1.8.5-1bionic.20210921.184400 [58.0 kB]
# Get:57 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-bondpy amd64 1.8.5-1bionic.20210921.202838 [15.4 kB]
# Get:58 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-bond-core amd64 1.8.5-1bionic.20210921.203237 [2,604 B]
# Get:59 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-diagnostic-msgs amd64 1.12.8-1bionic.20210505.010947 [32.2 kB]
# Get:60 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-geometry-msgs amd64 1.12.8-1bionic.20210505.011050 [66.8 kB]
# Get:61 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-nav-msgs amd64 1.12.8-1bionic.20210505.012414 [66.5 kB]
# Get:62 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-sensor-msgs amd64 1.12.8-1bionic.20210921.205104 [133 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic/main amd64 docutils-doc all 0.14+dfsg-3 [913 kB]
# Get:64 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-shape-msgs amd64 1.12.8-1bionic.20210505.011747 [22.7 kB]
# Get:65 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-stereo-msgs amd64 1.12.8-1bionic.20210921.210857 [18.9 kB]
# Get:66 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosbag-migration-rule amd64 1.0.0-0bionic.20200801.040144 [4,624 B]
# Get:67 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-trajectory-msgs amd64 1.12.8-1bionic.20210505.011758 [28.1 kB]
# Get:68 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-visualization-msgs amd64 1.12.8-1bionic.20210505.011924 [70.7 kB]
# Get:69 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-common-msgs amd64 1.12.8-1bionic.20210921.211124 [2,812 B]
# Get:70 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosmsg amd64 1.14.12-1bionic.20210921.205108 [22.6 kB]
# Get:71 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosservice amd64 1.14.12-1bionic.20210921.205347 [18.6 kB]
# Get:72 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-dynamic-reconfigure amd64 1.6.3-1bionic.20210921.210839 [94.6 kB]
# Get:73 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-message-filters amd64 1.14.12-1bionic.20210921.204209 [33.5 kB]
# Get:74 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-mk amd64 1.14.9-1bionic.20210505.012214 [10.2 kB]
# Get:75 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosbash amd64 1.14.9-1bionic.20201016.105914 [20.3 kB]
# Get:76 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosboost-cfg amd64 1.14.9-1bionic.20201015.020311 [13.7 kB]
# Get:77 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-roscreate amd64 1.14.9-1bionic.20201017.031701 [12.1 kB]
# Get:78 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-roslang amd64 1.14.9-1bionic.20201017.032441 [5,888 B]
# Get:79 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosmake amd64 1.14.9-1bionic.20201015.052555 [32.5 kB]
# Get:80 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-ros amd64 1.14.9-1bionic.20210505.012339 [1,884 B]
# Get:81 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-roslisp amd64 1.9.24-1bionic.20210505.012221 [97.9 kB]
# Get:82 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosnode amd64 1.14.12-1bionic.20210921.205145 [20.6 kB]
# Get:83 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-roswtf amd64 1.14.12-1bionic.20210921.211028 [41.2 kB]
# Get:84 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-ros-comm amd64 1.14.12-1bionic.20210921.221311 [3,184 B]
# Get:85 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-roscpp-core amd64 0.6.14-1bionic.20200801.065849 [1,744 B]
# Get:86 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-cmake-modules amd64 0.4.2-0bionic.20201015.021712 [17.8 kB]
# Get:87 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-nodelet amd64 1.9.16-0bionic.20210921.185826 [154 kB]
# Get:88 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-nodelet-topic-tools amd64 1.9.16-0bionic.20210921.211308 [15.9 kB]
# Get:89 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-nodelet-core amd64 1.9.16-0bionic.20210921.221411 [2,408 B]
# Get:90 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-rosconsole-bridge amd64 0.5.3-0bionic.20210505.012837 [12.0 kB]
# Get:91 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-ros-core amd64 1.4.1-0bionic.20210921.221409 [2,176 B]
# Get:92 http://packages.ros.org/ros/ubuntu bionic/main amd64 ros-melodic-ros-base amd64 1.4.1-0bionic.20210921.221525 [1,920 B]
# Get:93 http://archive.ubuntu.com/ubuntu bionic/universe amd64 googletest amd64 1.8.0-6 [652 kB]
# Get:94 http://archive.ubuntu.com/ubuntu bionic/universe amd64 google-mock amd64 1.8.0-6 [2,972 B]
# Get:95 http://archive.ubuntu.com/ubuntu bionic/main amd64 libapr1 amd64 1.6.3-2 [90.9 kB]
# Get:96 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsctp1 amd64 1.0.17+dfsg-2 [8,008 B]
# Get:97 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsctp-dev amd64 1.0.17+dfsg-2 [61.9 kB]
# Get:98 http://archive.ubuntu.com/ubuntu bionic/main amd64 libapr1-dev amd64 1.6.3-2 [690 kB]
# Get:99 http://archive.ubuntu.com/ubuntu bionic/main amd64 libaprutil1 amd64 1.6.1-2 [84.4 kB]
# Get:100 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-common all 2.4.45+dfsg-1ubuntu1.10 [15.8 kB]
# Get:101 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-2.4-2 amd64 2.4.45+dfsg-1ubuntu1.10 [154 kB]
# Get:102 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap2-dev amd64 2.4.45+dfsg-1ubuntu1.10 [261 kB]
# Get:103 http://archive.ubuntu.com/ubuntu bionic/main amd64 libaprutil1-dev amd64 1.6.1-2 [391 kB]
# Get:104 http://archive.ubuntu.com/ubuntu bionic/main amd64 libassuan-dev amd64 2.5.1-2 [92.1 kB]
# Get:105 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libconsole-bridge0.4 amd64 0.4.0+dfsg-2 [8,168 B]
# Get:106 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgpgme11 amd64 1.10.0-1ubuntu2 [111 kB]
# Get:107 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgtest-dev amd64 1.8.0-6 [2,718 B]
# Get:108 http://archive.ubuntu.com/ubuntu bionic/universe amd64 liblog4cxx10v5 amd64 0.10.0-13ubuntu2 [400 kB]
# Get:109 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnotify4 amd64 0.7.7-3 [17.3 kB]
# Get:110 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpocofoundation50 amd64 1.8.0.1-1ubuntu4 [440 kB]
# Get:111 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpococrypto50 amd64 1.8.0.1-1ubuntu4 [66.9 kB]
# Get:112 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpocodata50 amd64 1.8.0.1-1ubuntu4 [377 kB]
# Get:113 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpocojson50 amd64 1.8.0.1-1ubuntu4 [94.2 kB]
# Get:114 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpocodatamysql50 amd64 1.8.0.1-1ubuntu4 [46.4 kB]
# Get:115 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpoconet50 amd64 1.8.0.1-1ubuntu4 [313 kB]
# Get:116 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpocomongodb50 amd64 1.8.0.1-1ubuntu4 [67.2 kB]
# Get:117 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpocoxml50 amd64 1.8.0.1-1ubuntu4 [128 kB]
# Get:118 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpocoutil50 amd64 1.8.0.1-1ubuntu4 [120 kB]
# Get:119 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpoconetssl50 amd64 1.8.0.1-1ubuntu4 [74.7 kB]
# Get:120 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpocodataodbc50 amd64 1.8.0.1-1ubuntu4 [210 kB]
# Get:121 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpocodatasqlite50 amd64 1.8.0.1-1ubuntu4 [92.6 kB]
# Get:122 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpocoredis50 amd64 1.8.0.1-1ubuntu4 [45.6 kB]
# Get:123 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpocozip50 amd64 1.8.0.1-1ubuntu4 [84.6 kB]
# Get:124 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpoco-dev amd64 1.8.0.1-1ubuntu4 [518 kB]
# Get:125 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libtinyxml2-6 amd64 6.0.0+dfsg-1 [27.9 kB]
# Get:126 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwxbase3.0-0v5 amd64 3.0.4+dfsg-3 [954 kB]
# Get:127 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwxgtk3.0-gtk3-0v5 amd64 3.0.4+dfsg-3 [4,154 kB]
# Get:128 http://archive.ubuntu.com/ubuntu bionic/main amd64 notification-daemon amd64 3.20.0-3 [36.9 kB]
# Get:129 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-asn1crypto all 0.24.0-1 [72.7 kB]
# Get:130 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-six all 1.11.0-2 [11.3 kB]
# Get:131 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-dateutil all 2.6.1-1 [60.6 kB]
# Get:132 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-roman all 2.0.0-3 [8,548 B]
# Get:133 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-docutils all 0.14+dfsg-3 [365 kB]
# Get:134 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pyparsing all 2.2.0+dfsg1-2 [52.1 kB]
# Get:135 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-cffi-backend amd64 1.11.5-1 [63.4 kB]
# Get:136 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pkg-resources all 39.0.1-2 [128 kB]
# Get:137 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-chardet all 3.0.4-1 [80.3 kB]
# Get:138 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-enum34 all 1.1.6-2 [34.8 kB]
# Get:139 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-idna all 2.6-1 [32.4 kB]
# Get:140 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-ipaddress all 1.0.17-1 [18.2 kB]
# Get:141 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-cryptography amd64 2.1.4-1ubuntu1.4 [276 kB]
# Get:142 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-defusedxml all 0.5.0-1ubuntu1 [35.1 kB]
# Get:143 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-empy all 3.3.2-1build1 [72.5 kB]
# Get:144 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python-gnupg all 0.4.1-1ubuntu1.18.04.1 [17.0 kB]
# Get:145 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-netifaces amd64 0.10.4-0.1build4 [16.6 kB]
# Get:146 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-nose all 1.3.7-3 [116 kB]
# Get:147 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-olefile all 0.45.1-1 [33.2 kB]
# Get:148 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pyasn1 all 0.4.2-3 [46.7 kB]
# Get:149 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-paramiko all 2.0.0-1ubuntu1.2 [110 kB]
# Get:150 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-pil amd64 5.1.0-1ubuntu0.7 [303 kB]
# Get:151 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pycryptodome amd64 3.4.7-1ubuntu1 [4,755 kB]
# Get:152 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-pygments all 2.2.0+dfsg-1ubuntu0.2 [576 kB]
# Get:153 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-yaml amd64 3.12-1build2 [115 kB]
# Get:154 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-setuptools all 39.0.1-2 [329 kB]
# Get:155 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-wxversion all 3.0.2.0+dfsg-7 [12.4 kB]
# Get:156 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-wxgtk3.0 amd64 3.0.2.0+dfsg-7 [5,072 kB]
# Get:157 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-wxtools all 3.0.2.0+dfsg-7 [8,040 B]
# Get:158 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libconsole-bridge-dev amd64 0.4.0+dfsg-2 [6,596 B]
# Get:159 http://archive.ubuntu.com/ubuntu bionic/universe amd64 liblog4cxx-dev amd64 0.10.0-13ubuntu2 [857 kB]
# Get:160 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libtinyxml2-dev amd64 6.0.0+dfsg-1 [17.6 kB]
# Get:161 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgpgme-dev amd64 1.10.0-1ubuntu2 [306 kB]
# Get:162 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 liblz4-dev amd64 0.0~r131-2ubuntu3.1 [61.7 kB]
# Get:163 http://archive.ubuntu.com/ubuntu bionic/universe amd64 sbcl amd64 2:1.4.5-1 [8,580 kB]
# Fetched 38.9 MB in 5s (8,618 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 163.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package sgml-base.
# (Reading database ... 155320 files and directories currently installed.)
# Preparing to unpack .../sgml-base_1.29_all.deb ...
# Unpacking sgml-base (1.29) ...
# Preparing to unpack .../liblz4-1_0.0~r131-2ubuntu3.1_amd64.deb ...
# Unpacking liblz4-1:amd64 (0.0~r131-2ubuntu3.1) over (0.0~r131-2ubuntu3) ...
# Setting up liblz4-1:amd64 (0.0~r131-2ubuntu3.1) ...
# Selecting previously unselected package binfmt-support.
# (Reading database ... 155346 files and directories currently installed.)
# Preparing to unpack .../000-binfmt-support_2.1.8-2_amd64.deb ...
# Unpacking binfmt-support (2.1.8-2) ...
# Selecting previously unselected package xml-core.
# Preparing to unpack .../001-xml-core_0.18_all.deb ...
# Unpacking xml-core (0.18) ...
# Selecting previously unselected package docutils-common.
# Preparing to unpack .../002-docutils-common_0.14+dfsg-3_all.deb ...
# Unpacking docutils-common (0.14+dfsg-3) ...
# Selecting previously unselected package docutils-doc.
# Preparing to unpack .../003-docutils-doc_0.14+dfsg-3_all.deb ...
# Unpacking docutils-doc (0.14+dfsg-3) ...
# Selecting previously unselected package googletest:amd64.
# Preparing to unpack .../004-googletest_1.8.0-6_amd64.deb ...
# Unpacking googletest:amd64 (1.8.0-6) ...
# Selecting previously unselected package google-mock:amd64.
# Preparing to unpack .../005-google-mock_1.8.0-6_amd64.deb ...
# Unpacking google-mock:amd64 (1.8.0-6) ...
# Selecting previously unselected package libapr1:amd64.
# Preparing to unpack .../006-libapr1_1.6.3-2_amd64.deb ...
# Unpacking libapr1:amd64 (1.6.3-2) ...
# Selecting previously unselected package libsctp1:amd64.
# Preparing to unpack .../007-libsctp1_1.0.17+dfsg-2_amd64.deb ...
# Unpacking libsctp1:amd64 (1.0.17+dfsg-2) ...
# Selecting previously unselected package libsctp-dev:amd64.
# Preparing to unpack .../008-libsctp-dev_1.0.17+dfsg-2_amd64.deb ...
# Unpacking libsctp-dev:amd64 (1.0.17+dfsg-2) ...
# Selecting previously unselected package libapr1-dev.
# Preparing to unpack .../009-libapr1-dev_1.6.3-2_amd64.deb ...
# Unpacking libapr1-dev (1.6.3-2) ...
# Selecting previously unselected package libaprutil1:amd64.
# Preparing to unpack .../010-libaprutil1_1.6.1-2_amd64.deb ...
# Unpacking libaprutil1:amd64 (1.6.1-2) ...
# Preparing to unpack .../011-libldap-common_2.4.45+dfsg-1ubuntu1.10_all.deb ...
# Unpacking libldap-common (2.4.45+dfsg-1ubuntu1.10) over (2.4.45+dfsg-1ubuntu1.8) ...
# Preparing to unpack .../012-libldap-2.4-2_2.4.45+dfsg-1ubuntu1.10_amd64.deb ...
# Unpacking libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) over (2.4.45+dfsg-1ubuntu1.8) ...
# Selecting previously unselected package libldap2-dev:amd64.
# Preparing to unpack .../013-libldap2-dev_2.4.45+dfsg-1ubuntu1.10_amd64.deb ...
# Unpacking libldap2-dev:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# Selecting previously unselected package libaprutil1-dev.
# Preparing to unpack .../014-libaprutil1-dev_1.6.1-2_amd64.deb ...
# Unpacking libaprutil1-dev (1.6.1-2) ...
# Selecting previously unselected package libassuan-dev.
# Preparing to unpack .../015-libassuan-dev_2.5.1-2_amd64.deb ...
# Unpacking libassuan-dev (2.5.1-2) ...
# Selecting previously unselected package libconsole-bridge0.4:amd64.
# Preparing to unpack .../016-libconsole-bridge0.4_0.4.0+dfsg-2_amd64.deb ...
# Unpacking libconsole-bridge0.4:amd64 (0.4.0+dfsg-2) ...
# Selecting previously unselected package libgpgme11:amd64.
# Preparing to unpack .../017-libgpgme11_1.10.0-1ubuntu2_amd64.deb ...
# Unpacking libgpgme11:amd64 (1.10.0-1ubuntu2) ...
# Selecting previously unselected package libgtest-dev:amd64.
# Preparing to unpack .../018-libgtest-dev_1.8.0-6_amd64.deb ...
# Unpacking libgtest-dev:amd64 (1.8.0-6) ...
# Selecting previously unselected package liblog4cxx10v5:amd64.
# Preparing to unpack .../019-liblog4cxx10v5_0.10.0-13ubuntu2_amd64.deb ...
# Unpacking liblog4cxx10v5:amd64 (0.10.0-13ubuntu2) ...
# Selecting previously unselected package libnotify4:amd64.
# Preparing to unpack .../020-libnotify4_0.7.7-3_amd64.deb ...
# Unpacking libnotify4:amd64 (0.7.7-3) ...
# Selecting previously unselected package libpocofoundation50.
# Preparing to unpack .../021-libpocofoundation50_1.8.0.1-1ubuntu4_amd64.deb ...
# Unpacking libpocofoundation50 (1.8.0.1-1ubuntu4) ...
# Selecting previously unselected package libpococrypto50.
# Preparing to unpack .../022-libpococrypto50_1.8.0.1-1ubuntu4_amd64.deb ...
# Unpacking libpococrypto50 (1.8.0.1-1ubuntu4) ...
# Selecting previously unselected package libpocodata50.
# Preparing to unpack .../023-libpocodata50_1.8.0.1-1ubuntu4_amd64.deb ...
# Unpacking libpocodata50 (1.8.0.1-1ubuntu4) ...
# Selecting previously unselected package libpocojson50.
# Preparing to unpack .../024-libpocojson50_1.8.0.1-1ubuntu4_amd64.deb ...
# Unpacking libpocojson50 (1.8.0.1-1ubuntu4) ...
# Selecting previously unselected package libpocodatamysql50.
# Preparing to unpack .../025-libpocodatamysql50_1.8.0.1-1ubuntu4_amd64.deb ...
# Unpacking libpocodatamysql50 (1.8.0.1-1ubuntu4) ...
# Selecting previously unselected package libpoconet50.
# Preparing to unpack .../026-libpoconet50_1.8.0.1-1ubuntu4_amd64.deb ...
# Unpacking libpoconet50 (1.8.0.1-1ubuntu4) ...
# Selecting previously unselected package libpocomongodb50.
# Preparing to unpack .../027-libpocomongodb50_1.8.0.1-1ubuntu4_amd64.deb ...
# Unpacking libpocomongodb50 (1.8.0.1-1ubuntu4) ...
# Selecting previously unselected package libpocoxml50.
# Preparing to unpack .../028-libpocoxml50_1.8.0.1-1ubuntu4_amd64.deb ...
# Unpacking libpocoxml50 (1.8.0.1-1ubuntu4) ...
# Selecting previously unselected package libpocoutil50.
# Preparing to unpack .../029-libpocoutil50_1.8.0.1-1ubuntu4_amd64.deb ...
# Unpacking libpocoutil50 (1.8.0.1-1ubuntu4) ...
# Selecting previously unselected package libpoconetssl50.
# Preparing to unpack .../030-libpoconetssl50_1.8.0.1-1ubuntu4_amd64.deb ...
# Unpacking libpoconetssl50 (1.8.0.1-1ubuntu4) ...
# Selecting previously unselected package libpocodataodbc50.
# Preparing to unpack .../031-libpocodataodbc50_1.8.0.1-1ubuntu4_amd64.deb ...
# Unpacking libpocodataodbc50 (1.8.0.1-1ubuntu4) ...
# Selecting previously unselected package libpocodatasqlite50.
# Preparing to unpack .../032-libpocodatasqlite50_1.8.0.1-1ubuntu4_amd64.deb ...
# Unpacking libpocodatasqlite50 (1.8.0.1-1ubuntu4) ...
# Selecting previously unselected package libpocoredis50.
# Preparing to unpack .../033-libpocoredis50_1.8.0.1-1ubuntu4_amd64.deb ...
# Unpacking libpocoredis50 (1.8.0.1-1ubuntu4) ...
# Selecting previously unselected package libpocozip50.
# Preparing to unpack .../034-libpocozip50_1.8.0.1-1ubuntu4_amd64.deb ...
# Unpacking libpocozip50 (1.8.0.1-1ubuntu4) ...
# Selecting previously unselected package libpoco-dev.
# Preparing to unpack .../035-libpoco-dev_1.8.0.1-1ubuntu4_amd64.deb ...
# Unpacking libpoco-dev (1.8.0.1-1ubuntu4) ...
# Selecting previously unselected package libtinyxml2-6:amd64.
# Preparing to unpack .../036-libtinyxml2-6_6.0.0+dfsg-1_amd64.deb ...
# Unpacking libtinyxml2-6:amd64 (6.0.0+dfsg-1) ...
# Selecting previously unselected package libwxbase3.0-0v5:amd64.
# Preparing to unpack .../037-libwxbase3.0-0v5_3.0.4+dfsg-3_amd64.deb ...
# Unpacking libwxbase3.0-0v5:amd64 (3.0.4+dfsg-3) ...
# Selecting previously unselected package libwxgtk3.0-gtk3-0v5:amd64.
# Preparing to unpack .../038-libwxgtk3.0-gtk3-0v5_3.0.4+dfsg-3_amd64.deb ...
# Unpacking libwxgtk3.0-gtk3-0v5:amd64 (3.0.4+dfsg-3) ...
# Selecting previously unselected package notification-daemon.
# Preparing to unpack .../039-notification-daemon_3.20.0-3_amd64.deb ...
# Unpacking notification-daemon (3.20.0-3) ...
# Selecting previously unselected package python-asn1crypto.
# Preparing to unpack .../040-python-asn1crypto_0.24.0-1_all.deb ...
# Unpacking python-asn1crypto (0.24.0-1) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../041-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-dateutil.
# Preparing to unpack .../042-python-dateutil_2.6.1-1_all.deb ...
# Unpacking python-dateutil (2.6.1-1) ...
# Selecting previously unselected package python-roman.
# Preparing to unpack .../043-python-roman_2.0.0-3_all.deb ...
# Unpacking python-roman (2.0.0-3) ...
# Selecting previously unselected package python-docutils.
# Preparing to unpack .../044-python-docutils_0.14+dfsg-3_all.deb ...
# Unpacking python-docutils (0.14+dfsg-3) ...
# Selecting previously unselected package python-pyparsing.
# Preparing to unpack .../045-python-pyparsing_2.2.0+dfsg1-2_all.deb ...
# Unpacking python-pyparsing (2.2.0+dfsg1-2) ...
# Selecting previously unselected package python-catkin-pkg-modules.
# Preparing to unpack .../046-python-catkin-pkg-modules_0.4.24-1_all.deb ...
# Unpacking python-catkin-pkg-modules (0.4.24-1) ...
# Selecting previously unselected package python-catkin-pkg.
# Preparing to unpack .../047-python-catkin-pkg_0.4.24-100_all.deb ...
# Unpacking python-catkin-pkg (0.4.24-100) ...
# Selecting previously unselected package python-cffi-backend.
# Preparing to unpack .../048-python-cffi-backend_1.11.5-1_amd64.deb ...
# Unpacking python-cffi-backend (1.11.5-1) ...
# Selecting previously unselected package python-pkg-resources.
# Preparing to unpack .../049-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-chardet.
# Preparing to unpack .../050-python-chardet_3.0.4-1_all.deb ...
# Unpacking python-chardet (3.0.4-1) ...
# Selecting previously unselected package python-enum34.
# Preparing to unpack .../051-python-enum34_1.1.6-2_all.deb ...
# Unpacking python-enum34 (1.1.6-2) ...
# Selecting previously unselected package python-idna.
# Preparing to unpack .../052-python-idna_2.6-1_all.deb ...
# Unpacking python-idna (2.6-1) ...
# Selecting previously unselected package python-ipaddress.
# Preparing to unpack .../053-python-ipaddress_1.0.17-1_all.deb ...
# Unpacking python-ipaddress (1.0.17-1) ...
# Selecting previously unselected package python-cryptography.
# Preparing to unpack .../054-python-cryptography_2.1.4-1ubuntu1.4_amd64.deb ...
# Unpacking python-cryptography (2.1.4-1ubuntu1.4) ...
# Selecting previously unselected package python-defusedxml.
# Preparing to unpack .../055-python-defusedxml_0.5.0-1ubuntu1_all.deb ...
# Unpacking python-defusedxml (0.5.0-1ubuntu1) ...
# Selecting previously unselected package python-empy.
# Preparing to unpack .../056-python-empy_3.3.2-1build1_all.deb ...
# Unpacking python-empy (3.3.2-1build1) ...
# Selecting previously unselected package python-gnupg.
# Preparing to unpack .../057-python-gnupg_0.4.1-1ubuntu1.18.04.1_all.deb ...
# Unpacking python-gnupg (0.4.1-1ubuntu1.18.04.1) ...
# Selecting previously unselected package python-netifaces.
# Preparing to unpack .../058-python-netifaces_0.10.4-0.1build4_amd64.deb ...
# Unpacking python-netifaces (0.10.4-0.1build4) ...
# Selecting previously unselected package python-nose.
# Preparing to unpack .../059-python-nose_1.3.7-3_all.deb ...
# Unpacking python-nose (1.3.7-3) ...
# Selecting previously unselected package python-olefile.
# Preparing to unpack .../060-python-olefile_0.45.1-1_all.deb ...
# Unpacking python-olefile (0.45.1-1) ...
# Selecting previously unselected package python-pyasn1.
# Preparing to unpack .../061-python-pyasn1_0.4.2-3_all.deb ...
# Unpacking python-pyasn1 (0.4.2-3) ...
# Selecting previously unselected package python-paramiko.
# Preparing to unpack .../062-python-paramiko_2.0.0-1ubuntu1.2_all.deb ...
# Unpacking python-paramiko (2.0.0-1ubuntu1.2) ...
# Selecting previously unselected package python-pil:amd64.
# Preparing to unpack .../063-python-pil_5.1.0-1ubuntu0.7_amd64.deb ...
# Unpacking python-pil:amd64 (5.1.0-1ubuntu0.7) ...
# Selecting previously unselected package python-pycryptodome.
# Preparing to unpack .../064-python-pycryptodome_3.4.7-1ubuntu1_amd64.deb ...
# Unpacking python-pycryptodome (3.4.7-1ubuntu1) ...
# Selecting previously unselected package python-pygments.
# Preparing to unpack .../065-python-pygments_2.2.0+dfsg-1ubuntu0.2_all.deb ...
# Unpacking python-pygments (2.2.0+dfsg-1ubuntu0.2) ...
# Selecting previously unselected package python-yaml.
# Preparing to unpack .../066-python-yaml_3.12-1build2_amd64.deb ...
# Unpacking python-yaml (3.12-1build2) ...
# Selecting previously unselected package python-rospkg-modules.
# Preparing to unpack .../067-python-rospkg-modules_1.4.0-1_all.deb ...
# Unpacking python-rospkg-modules (1.4.0-1) ...
# Selecting previously unselected package python-setuptools.
# Preparing to unpack .../068-python-setuptools_39.0.1-2_all.deb ...
# Unpacking python-setuptools (39.0.1-2) ...
# Selecting previously unselected package python-rosdistro-modules.
# Preparing to unpack .../069-python-rosdistro-modules_0.8.3-1_all.deb ...
# Unpacking python-rosdistro-modules (0.8.3-1) ...
# Selecting previously unselected package python-rosdistro.
# Preparing to unpack .../070-python-rosdistro_0.8.3-100_all.deb ...
# Unpacking python-rosdistro (0.8.3-100) ...
# Selecting previously unselected package python-rospkg.
# Preparing to unpack .../071-python-rospkg_1.4.0-100_all.deb ...
# Unpacking python-rospkg (1.4.0-100) ...
# Selecting previously unselected package python-rosdep-modules.
# Preparing to unpack .../072-python-rosdep-modules_0.21.0-1_all.deb ...
# Unpacking python-rosdep-modules (0.21.0-1) ...
# Selecting previously unselected package python-wxversion.
# Preparing to unpack .../073-python-wxversion_3.0.2.0+dfsg-7_all.deb ...
# Unpacking python-wxversion (3.0.2.0+dfsg-7) ...
# Selecting previously unselected package python-wxgtk3.0.
# Preparing to unpack .../074-python-wxgtk3.0_3.0.2.0+dfsg-7_amd64.deb ...
# Unpacking python-wxgtk3.0 (3.0.2.0+dfsg-7) ...
# Selecting previously unselected package python-wxtools.
# Preparing to unpack .../075-python-wxtools_3.0.2.0+dfsg-7_all.deb ...
# Unpacking python-wxtools (3.0.2.0+dfsg-7) ...
# Selecting previously unselected package ros-melodic-catkin.
# Preparing to unpack .../076-ros-melodic-catkin_0.7.29-1bionic.20201014.191449_amd64.deb ...
# Unpacking ros-melodic-catkin (0.7.29-1bionic.20201014.191449) ...
# Selecting previously unselected package ros-melodic-genmsg.
# Preparing to unpack .../077-ros-melodic-genmsg_0.5.16-1bionic.20201017.031430_amd64.deb ...
# Unpacking ros-melodic-genmsg (0.5.16-1bionic.20201017.031430) ...
# Selecting previously unselected package ros-melodic-gencpp.
# Preparing to unpack .../078-ros-melodic-gencpp_0.6.5-1bionic.20201017.032453_amd64.deb ...
# Unpacking ros-melodic-gencpp (0.6.5-1bionic.20201017.032453) ...
# Selecting previously unselected package ros-melodic-geneus.
# Preparing to unpack .../079-ros-melodic-geneus_2.2.6-0bionic.20201017.032432_amd64.deb ...
# Unpacking ros-melodic-geneus (2.2.6-0bionic.20201017.032432) ...
# Selecting previously unselected package ros-melodic-genlisp.
# Preparing to unpack .../080-ros-melodic-genlisp_0.4.16-0bionic.20201017.032516_amd64.deb ...
# Unpacking ros-melodic-genlisp (0.4.16-0bionic.20201017.032516) ...
# Selecting previously unselected package ros-melodic-gennodejs.
# Preparing to unpack .../081-ros-melodic-gennodejs_2.0.1-0bionic.20201017.032446_amd64.deb ...
# Unpacking ros-melodic-gennodejs (2.0.1-0bionic.20201017.032446) ...
# Selecting previously unselected package ros-melodic-genpy.
# Preparing to unpack .../082-ros-melodic-genpy_0.6.16-1bionic.20210505.005001_amd64.deb ...
# Unpacking ros-melodic-genpy (0.6.16-1bionic.20210505.005001) ...
# Selecting previously unselected package ros-melodic-message-generation.
# Preparing to unpack .../083-ros-melodic-message-generation_0.4.1-1bionic.20210505.005154_amd64.deb ...
# Unpacking ros-melodic-message-generation (0.4.1-1bionic.20210505.005154) ...
# Selecting previously unselected package libconsole-bridge-dev:amd64.
# Preparing to unpack .../084-libconsole-bridge-dev_0.4.0+dfsg-2_amd64.deb ...
# Unpacking libconsole-bridge-dev:amd64 (0.4.0+dfsg-2) ...
# Selecting previously unselected package ros-melodic-cpp-common.
# Preparing to unpack .../085-ros-melodic-cpp-common_0.6.14-1bionic.20200801.035855_amd64.deb ...
# Unpacking ros-melodic-cpp-common (0.6.14-1bionic.20200801.035855) ...
# Selecting previously unselected package ros-melodic-rostime.
# Preparing to unpack .../086-ros-melodic-rostime_0.6.14-1bionic.20200801.051100_amd64.deb ...
# Unpacking ros-melodic-rostime (0.6.14-1bionic.20200801.051100) ...
# Selecting previously unselected package ros-melodic-roscpp-traits.
# Preparing to unpack .../087-ros-melodic-roscpp-traits_0.6.14-1bionic.20200801.063118_amd64.deb ...
# Unpacking ros-melodic-roscpp-traits (0.6.14-1bionic.20200801.063118) ...
# Selecting previously unselected package ros-melodic-roscpp-serialization.
# Preparing to unpack .../088-ros-melodic-roscpp-serialization_0.6.14-1bionic.20200801.063506_amd64.deb ...
# Unpacking ros-melodic-roscpp-serialization (0.6.14-1bionic.20200801.063506) ...
# Selecting previously unselected package ros-melodic-message-runtime.
# Preparing to unpack .../089-ros-melodic-message-runtime_0.4.12-0bionic.20210505.005252_amd64.deb ...
# Unpacking ros-melodic-message-runtime (0.4.12-0bionic.20210505.005252) ...
# Selecting previously unselected package ros-melodic-std-msgs.
# Preparing to unpack .../090-ros-melodic-std-msgs_0.5.12-0bionic.20210505.005906_amd64.deb ...
# Unpacking ros-melodic-std-msgs (0.5.12-0bionic.20210505.005906) ...
# Selecting previously unselected package ros-melodic-actionlib-msgs.
# Preparing to unpack .../091-ros-melodic-actionlib-msgs_1.12.8-1bionic.20210505.010611_amd64.deb ...
# Unpacking ros-melodic-actionlib-msgs (1.12.8-1bionic.20210505.010611) ...
# Selecting previously unselected package liblog4cxx-dev:amd64.
# Preparing to unpack .../092-liblog4cxx-dev_0.10.0-13ubuntu2_amd64.deb ...
# Unpacking liblog4cxx-dev:amd64 (0.10.0-13ubuntu2) ...
# Selecting previously unselected package ros-melodic-rosbuild.
# Preparing to unpack .../093-ros-melodic-rosbuild_1.14.9-1bionic.20210505.005821_amd64.deb ...
# Unpacking ros-melodic-rosbuild (1.14.9-1bionic.20210505.005821) ...
# Selecting previously unselected package ros-melodic-rosconsole.
# Preparing to unpack .../094-ros-melodic-rosconsole_1.13.18-1bionic.20210505.012210_amd64.deb ...
# Unpacking ros-melodic-rosconsole (1.13.18-1bionic.20210505.012210) ...
# Selecting previously unselected package ros-melodic-rosgraph-msgs.
# Preparing to unpack .../095-ros-melodic-rosgraph-msgs_1.11.2-0bionic.20210505.012040_amd64.deb ...
# Unpacking ros-melodic-rosgraph-msgs (1.11.2-0bionic.20210505.012040) ...
# Selecting previously unselected package ros-melodic-xmlrpcpp.
# Preparing to unpack .../096-ros-melodic-xmlrpcpp_1.14.12-1bionic.20210921.180110_amd64.deb ...
# Unpacking ros-melodic-xmlrpcpp (1.14.12-1bionic.20210921.180110) ...
# Selecting previously unselected package ros-melodic-roscpp.
# Preparing to unpack .../097-ros-melodic-roscpp_1.14.12-1bionic.20210921.180348_amd64.deb ...
# ...
# Selecting previously unselected package ros-melodic-rosboost-cfg.
# Preparing to unpack .../143-ros-melodic-rosboost-cfg_1.14.9-1bionic.20201015.020311_amd64.deb ...
# Unpacking ros-melodic-rosboost-cfg (1.14.9-1bionic.20201015.020311) ...
# Selecting previously unselected package ros-melodic-roscreate.
# Preparing to unpack .../144-ros-melodic-roscreate_1.14.9-1bionic.20201017.031701_amd64.deb ...
# Unpacking ros-melodic-roscreate (1.14.9-1bionic.20201017.031701) ...
# Selecting previously unselected package ros-melodic-roslang.
# Preparing to unpack .../145-ros-melodic-roslang_1.14.9-1bionic.20201017.032441_amd64.deb ...
# Unpacking ros-melodic-roslang (1.14.9-1bionic.20201017.032441) ...
# Selecting previously unselected package ros-melodic-rosmake.
# Preparing to unpack .../146-ros-melodic-rosmake_1.14.9-1bionic.20201015.052555_amd64.deb ...
# Unpacking ros-melodic-rosmake (1.14.9-1bionic.20201015.052555) ...
# Selecting previously unselected package ros-melodic-ros.
# Preparing to unpack .../147-ros-melodic-ros_1.14.9-1bionic.20210505.012339_amd64.deb ...
# Unpacking ros-melodic-ros (1.14.9-1bionic.20210505.012339) ...
# Selecting previously unselected package sbcl.
# Preparing to unpack .../148-sbcl_2%3a1.4.5-1_amd64.deb ...
# Unpacking sbcl (2:1.4.5-1) ...
# Selecting previously unselected package ros-melodic-roslisp.
# Preparing to unpack .../149-ros-melodic-roslisp_1.9.24-1bionic.20210505.012221_amd64.deb ...
# Unpacking ros-melodic-roslisp (1.9.24-1bionic.20210505.012221) ...
# Selecting previously unselected package ros-melodic-rosnode.
# Preparing to unpack .../150-ros-melodic-rosnode_1.14.12-1bionic.20210921.205145_amd64.deb ...
# Unpacking ros-melodic-rosnode (1.14.12-1bionic.20210921.205145) ...
# Selecting previously unselected package ros-melodic-roswtf.
# Preparing to unpack .../151-ros-melodic-roswtf_1.14.12-1bionic.20210921.211028_amd64.deb ...
# Unpacking ros-melodic-roswtf (1.14.12-1bionic.20210921.211028) ...
# Selecting previously unselected package ros-melodic-ros-comm.
# Preparing to unpack .../152-ros-melodic-ros-comm_1.14.12-1bionic.20210921.221311_amd64.deb ...
# Unpacking ros-melodic-ros-comm (1.14.12-1bionic.20210921.221311) ...
# Selecting previously unselected package ros-melodic-roscpp-core.
# Preparing to unpack .../153-ros-melodic-roscpp-core_0.6.14-1bionic.20200801.065849_amd64.deb ...
# Unpacking ros-melodic-roscpp-core (0.6.14-1bionic.20200801.065849) ...
# Selecting previously unselected package ros-melodic-cmake-modules.
# Preparing to unpack .../154-ros-melodic-cmake-modules_0.4.2-0bionic.20201015.021712_amd64.deb ...
# Unpacking ros-melodic-cmake-modules (0.4.2-0bionic.20201015.021712) ...
# Selecting previously unselected package ros-melodic-nodelet.
# Preparing to unpack .../155-ros-melodic-nodelet_1.9.16-0bionic.20210921.185826_amd64.deb ...
# Unpacking ros-melodic-nodelet (1.9.16-0bionic.20210921.185826) ...
# Selecting previously unselected package ros-melodic-nodelet-topic-tools.
# Preparing to unpack .../156-ros-melodic-nodelet-topic-tools_1.9.16-0bionic.20210921.211308_amd64.deb ...
# Unpacking ros-melodic-nodelet-topic-tools (1.9.16-0bionic.20210921.211308) ...
# Selecting previously unselected package ros-melodic-nodelet-core.
# Preparing to unpack .../157-ros-melodic-nodelet-core_1.9.16-0bionic.20210921.221411_amd64.deb ...
# Unpacking ros-melodic-nodelet-core (1.9.16-0bionic.20210921.221411) ...
# Selecting previously unselected package ros-melodic-rosconsole-bridge.
# Preparing to unpack .../158-ros-melodic-rosconsole-bridge_0.5.3-0bionic.20210505.012837_amd64.deb ...
# Unpacking ros-melodic-rosconsole-bridge (0.5.3-0bionic.20210505.012837) ...
# Selecting previously unselected package ros-melodic-ros-core.
# Preparing to unpack .../159-ros-melodic-ros-core_1.4.1-0bionic.20210921.221409_amd64.deb ...
# Unpacking ros-melodic-ros-core (1.4.1-0bionic.20210921.221409) ...
# Selecting previously unselected package ros-melodic-ros-base.
# Preparing to unpack .../160-ros-melodic-ros-base_1.4.1-0bionic.20210921.221525_amd64.deb ...
# Unpacking ros-melodic-ros-base (1.4.1-0bionic.20210921.221525) ...
# Setting up libtinyxml2-6:amd64 (6.0.0+dfsg-1) ...
# Setting up python-idna (2.6-1) ...
# Setting up libapr1:amd64 (1.6.3-2) ...
# Setting up binfmt-support (2.1.8-2) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/binfmt-support.service → /lib/systemd/system/binfmt-support.service.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libnotify4:amd64 (0.7.7-3) ...
# Setting up python-yaml (3.12-1build2) ...
# Setting up python-asn1crypto (0.24.0-1) ...
# Setting up python-defusedxml (0.5.0-1ubuntu1) ...
# Setting up libsctp1:amd64 (1.0.17+dfsg-2) ...
# Setting up libldap-common (2.4.45+dfsg-1ubuntu1.10) ...
# Setting up python-pycryptodome (3.4.7-1ubuntu1) ...
# Setting up libconsole-bridge0.4:amd64 (0.4.0+dfsg-2) ...
# Setting up ros-melodic-smclib (1.8.5-1bionic.20200801.035835) ...
# Setting up python-pyasn1 (0.4.2-3) ...
# Setting up python-wxversion (3.0.2.0+dfsg-7) ...
# Setting up ros-melodic-ros-environment (1.2.3-1bionic.20201015.052244) ...
# Setting up libtinyxml2-dev:amd64 (6.0.0+dfsg-1) ...
# Setting up ros-melodic-rosboost-cfg (1.14.9-1bionic.20201015.020311) ...
# Setting up sgml-base (1.29) ...
# Setting up python-pkg-resources (39.0.1-2) ...
# Setting up python-roman (2.0.0-3) ...
# Setting up ros-melodic-rosbag-migration-rule (1.0.0-0bionic.20200801.040144) ...
# Setting up python-netifaces (0.10.4-0.1build4) ...
# Setting up libwxbase3.0-0v5:amd64 (3.0.4+dfsg-3) ...
# Setting up libgpgme11:amd64 (1.10.0-1ubuntu2) ...
# Setting up python-cffi-backend (1.11.5-1) ...
# Setting up python-six (1.11.0-2) ...
# Setting up googletest:amd64 (1.8.0-6) ...
# Setting up python-pygments (2.2.0+dfsg-1ubuntu0.2) ...
# Setting up libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# Setting up python-empy (3.3.2-1build1) ...
# Setting up libaprutil1:amd64 (1.6.1-2) ...
# Setting up libassuan-dev (2.5.1-2) ...
# Setting up python-enum34 (1.1.6-2) ...
# Setting up libconsole-bridge-dev:amd64 (0.4.0+dfsg-2) ...
# Setting up docutils-doc (0.14+dfsg-3) ...
# Setting up libgtest-dev:amd64 (1.8.0-6) ...
# Setting up libwxgtk3.0-gtk3-0v5:amd64 (3.0.4+dfsg-3) ...
# Setting up sbcl (2:1.4.5-1) ...
# Setting up python-olefile (0.45.1-1) ...
# Setting up libgpgme-dev (1.10.0-1ubuntu2) ...
# Setting up xml-core (0.18) ...
# Setting up liblz4-dev:amd64 (0.0~r131-2ubuntu3.1) ...
# Setting up ros-melodic-cmake-modules (0.4.2-0bionic.20201015.021712) ...
# Setting up python-ipaddress (1.0.17-1) ...
# Setting up python-nose (1.3.7-3) ...
# Setting up python-pil:amd64 (5.1.0-1ubuntu0.7) ...
# Setting up python-gnupg (0.4.1-1ubuntu1.18.04.1) ...
# Setting up libpocofoundation50 (1.8.0.1-1ubuntu4) ...
# Setting up notification-daemon (3.20.0-3) ...
# Setting up python-pyparsing (2.2.0+dfsg1-2) ...
# Setting up libldap2-dev:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# Setting up libsctp-dev:amd64 (1.0.17+dfsg-2) ...
# Setting up ros-melodic-cpp-common (0.6.14-1bionic.20200801.035855) ...
# Setting up liblog4cxx10v5:amd64 (0.10.0-13ubuntu2) ...
# Setting up python-setuptools (39.0.1-2) ...
# Setting up google-mock:amd64 (1.8.0-6) ...
# Setting up python-chardet (3.0.4-1) ...
# Setting up libapr1-dev (1.6.3-2) ...
# Setting up ros-melodic-rostime (0.6.14-1bionic.20200801.051100) ...
# Setting up libpocodata50 (1.8.0.1-1ubuntu4) ...
# Setting up python-wxgtk3.0 (3.0.2.0+dfsg-7) ...
# update-alternatives: using /usr/lib/wx/python/wx3.0.pth to provide /usr/lib/wx/python/wx.pth (wx.pth) in auto mode
# Setting up libaprutil1-dev (1.6.1-2) ...
# Setting up libpocozip50 (1.8.0.1-1ubuntu4) ...
# Setting up libpocoxml50 (1.8.0.1-1ubuntu4) ...
# Setting up ros-melodic-roslz4 (1.14.12-1bionic.20210921.180139) ...
# Setting up python-dateutil (2.6.1-1) ...
# Setting up libpocojson50 (1.8.0.1-1ubuntu4) ...
# Setting up python-wxtools (3.0.2.0+dfsg-7) ...
# Setting up libpococrypto50 (1.8.0.1-1ubuntu4) ...
# Setting up ros-melodic-xmlrpcpp (1.14.12-1bionic.20210921.180110) ...
# Setting up liblog4cxx-dev:amd64 (0.10.0-13ubuntu2) ...
# Setting up ros-melodic-roscpp-traits (0.6.14-1bionic.20200801.063118) ...
# Setting up python-cryptography (2.1.4-1ubuntu1.4) ...
# Setting up libpocodatamysql50 (1.8.0.1-1ubuntu4) ...
# Setting up libpoconet50 (1.8.0.1-1ubuntu4) ...
# Setting up libpocoredis50 (1.8.0.1-1ubuntu4) ...
# Setting up libpocoutil50 (1.8.0.1-1ubuntu4) ...
# Setting up libpocodatasqlite50 (1.8.0.1-1ubuntu4) ...
# Setting up libpoconetssl50 (1.8.0.1-1ubuntu4) ...
# Setting up libpocodataodbc50 (1.8.0.1-1ubuntu4) ...
# Setting up libpocomongodb50 (1.8.0.1-1ubuntu4) ...
# Setting up ros-melodic-roscpp-serialization (0.6.14-1bionic.20200801.063506) ...
# Setting up python-paramiko (2.0.0-1ubuntu1.2) ...
# Setting up ros-melodic-roscpp-core (0.6.14-1bionic.20200801.065849) ...
# Setting up libpoco-dev (1.8.0.1-1ubuntu4) ...
# Setting up ros-melodic-class-loader (0.4.1-0bionic.20201015.033003) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for systemd (237-3ubuntu10.53) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for shared-mime-info (1.9-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for sgml-base (1.29) ...
# Setting up docutils-common (0.14+dfsg-3) ...
# Processing triggers for sgml-base (1.29) ...
# Setting up python-docutils (0.14+dfsg-3) ...
# update-alternatives: using /usr/share/docutils/scripts/python2/rst-buildhtml to provide /usr/bin/rst-buildhtml (rst-buildhtml) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python2/rst2html to provide /usr/bin/rst2html (rst2html) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python2/rst2html4 to provide /usr/bin/rst2html4 (rst2html4) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python2/rst2html5 to provide /usr/bin/rst2html5 (rst2html5) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python2/rst2latex to provide /usr/bin/rst2latex (rst2latex) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python2/rst2man to provide /usr/bin/rst2man (rst2man) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python2/rst2odt to provide /usr/bin/rst2odt (rst2odt) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python2/rst2odt_prepstyles to provide /usr/bin/rst2odt_prepstyles (rst2odt_prepstyles) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python2/rst2pseudoxml to provide /usr/bin/rst2pseudoxml (rst2pseudoxml) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python2/rst2s5 to provide /usr/bin/rst2s5 (rst2s5) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python2/rst2xetex to provide /usr/bin/rst2xetex (rst2xetex) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python2/rst2xml to provide /usr/bin/rst2xml (rst2xml) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python2/rstpep2html to provide /usr/bin/rstpep2html (rstpep2html) in auto mode
# Setting up python-catkin-pkg-modules (0.4.24-1) ...
# Setting up python-rospkg-modules (1.4.0-1) ...
# Setting up python-catkin-pkg (0.4.24-100) ...
# Setting up ros-melodic-catkin (0.7.29-1bionic.20201014.191449) ...
# Setting up python-rosdistro-modules (0.8.3-1) ...
# Setting up python-rospkg (1.4.0-100) ...
# Setting up ros-melodic-rosmake (1.14.9-1bionic.20201015.052555) ...
# Setting up ros-melodic-genmsg (0.5.16-1bionic.20201017.031430) ...
# Setting up ros-melodic-rosgraph (1.14.12-1bionic.20210921.180103) ...
# Setting up ros-melodic-gencpp (0.6.5-1bionic.20201017.032453) ...
# Setting up python-rosdistro (0.8.3-100) ...
# Setting up ros-melodic-genpy (0.6.16-1bionic.20210505.005001) ...
# Setting up python-rosdep-modules (0.21.0-1) ...
# Setting up ros-melodic-gennodejs (2.0.1-0bionic.20201017.032446) ...
# Setting up ros-melodic-roslang (1.14.9-1bionic.20201017.032441) ...
# Setting up ros-melodic-rosparam (1.14.12-1bionic.20210921.180319) ...
# Setting up ros-melodic-rosclean (1.14.9-1bionic.20201015.071027) ...
# Setting up ros-melodic-geneus (2.2.6-0bionic.20201017.032432) ...
# Setting up ros-melodic-rosmaster (1.14.12-1bionic.20210921.180319) ...
# Setting up ros-melodic-message-runtime (0.4.12-0bionic.20210505.005252) ...
# Setting up ros-melodic-std-msgs (0.5.12-0bionic.20210505.005906) ...
# Setting up ros-melodic-genlisp (0.4.16-0bionic.20201017.032516) ...
# Setting up ros-melodic-rospack (2.5.6-1bionic.20201015.070131) ...
# Setting up ros-melodic-std-srvs (1.11.2-0bionic.20210505.005914) ...
# Setting up ros-melodic-rosbash (1.14.9-1bionic.20201016.105914) ...
# Setting up ros-melodic-geometry-msgs (1.12.8-1bionic.20210505.011050) ...
# Setting up ros-melodic-bond (1.8.5-1bionic.20210505.010840) ...
# Setting up ros-melodic-diagnostic-msgs (1.12.8-1bionic.20210505.010947) ...
# Setting up ros-melodic-shape-msgs (1.12.8-1bionic.20210505.011747) ...
# Setting up ros-melodic-trajectory-msgs (1.12.8-1bionic.20210505.011758) ...
# Setting up ros-melodic-rosgraph-msgs (1.11.2-0bionic.20210505.012040) ...
# Setting up ros-melodic-message-generation (0.4.1-1bionic.20210505.005154) ...
# Setting up ros-melodic-roslisp (1.9.24-1bionic.20210505.012221) ...
# Setting up ros-melodic-roslib (1.14.9-1bionic.20201016.105810) ...
# Setting up ros-melodic-rosunit (1.14.9-1bionic.20201017.031507) ...
# Setting up ros-melodic-sensor-msgs (1.12.8-1bionic.20210921.205104) ...
# Setting up ros-melodic-roscreate (1.14.9-1bionic.20201017.031701) ...
# Setting up ros-melodic-visualization-msgs (1.12.8-1bionic.20210505.011924) ...
# Setting up ros-melodic-stereo-msgs (1.12.8-1bionic.20210921.210857) ...
# Setting up ros-melodic-rosbuild (1.14.9-1bionic.20210505.005821) ...
# Setting up ros-melodic-actionlib-msgs (1.12.8-1bionic.20210505.010611) ...
# Setting up ros-melodic-rosconsole (1.13.18-1bionic.20210505.012210) ...
# Setting up ros-melodic-roscpp (1.14.12-1bionic.20210921.180348) ...
# Setting up ros-melodic-rosout (1.14.12-1bionic.20210921.202545) ...
# Setting up ros-melodic-roslaunch (1.14.12-1bionic.20210921.202835) ...
# Setting up ros-melodic-rosconsole-bridge (0.5.3-0bionic.20210505.012837) ...
# Setting up ros-melodic-nav-msgs (1.12.8-1bionic.20210505.012414) ...
# Setting up ros-melodic-topic-tools (1.14.12-1bionic.20210921.204541) ...
# Setting up ros-melodic-mk (1.14.9-1bionic.20210505.012214) ...
# Setting up ros-melodic-common-msgs (1.12.8-1bionic.20210921.211124) ...
# Setting up ros-melodic-pluginlib (1.12.1-0bionic.20210505.012832) ...
# Setting up ros-melodic-rospy (1.14.12-1bionic.20210921.181015) ...
# Setting up ros-melodic-ros (1.14.9-1bionic.20210505.012339) ...
# Setting up ros-melodic-bondpy (1.8.5-1bionic.20210921.202838) ...
# Setting up ros-melodic-message-filters (1.14.12-1bionic.20210921.204209) ...
# Setting up ros-melodic-bondcpp (1.8.5-1bionic.20210921.184400) ...
# Setting up ros-melodic-nodelet (1.9.16-0bionic.20210921.185826) ...
# Setting up ros-melodic-rostest (1.14.12-1bionic.20210921.203603) ...
# Setting up ros-melodic-rosbag-storage (1.14.12-1bionic.20210921.203950) ...
# Setting up ros-melodic-bond-core (1.8.5-1bionic.20210921.203237) ...
# Setting up ros-melodic-rosbag (1.14.12-1bionic.20210921.204714) ...
# Setting up ros-melodic-rosmsg (1.14.12-1bionic.20210921.205108) ...
# Setting up ros-melodic-rostopic (1.14.12-1bionic.20210921.205048) ...
# Setting up ros-melodic-rosservice (1.14.12-1bionic.20210921.205347) ...
# Setting up ros-melodic-dynamic-reconfigure (1.6.3-1bionic.20210921.210839) ...
# Setting up ros-melodic-actionlib (1.12.1-1bionic.20210921.205646) ...
# Setting up ros-melodic-rosnode (1.14.12-1bionic.20210921.205145) ...
# Setting up ros-melodic-nodelet-topic-tools (1.9.16-0bionic.20210921.211308) ...
# Setting up ros-melodic-nodelet-core (1.9.16-0bionic.20210921.221411) ...
# Setting up ros-melodic-roswtf (1.14.12-1bionic.20210921.211028) ...
# Setting up ros-melodic-ros-comm (1.14.12-1bionic.20210921.221311) ...
# Setting up ros-melodic-ros-core (1.4.1-0bionic.20210921.221409) ...
# Setting up ros-melodic-ros-base (1.4.1-0bionic.20210921.221525) ...

# %% [markdown]
# ### Install Additional Packages

# %%
# !sudo apt install python-rospkg
# !pip install rospkg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-rospkg is already the newest version (1.4.0-100).
# python-rospkg set to manually installed.
# The following package was automatically installed and is no longer required:
#   libnvidia-common-470
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 64 not upgraded.
# Collecting rospkg
#   Downloading rospkg-1.4.0-py3-none-any.whl (36 kB)
# Collecting catkin-pkg
#   Downloading catkin_pkg-0.4.24-py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 2.4 MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from rospkg) (3.13)
# Requirement already satisfied: docutils in /usr/local/lib/python3.7/dist-packages (from catkin-pkg->rospkg) (0.17.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from catkin-pkg->rospkg) (3.0.7)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from catkin-pkg->rospkg) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->catkin-pkg->rospkg) (1.15.0)
# Installing collected packages: catkin-pkg, rospkg
# Successfully installed catkin-pkg-0.4.24 rospkg-1.4.0

# %% [markdown]
# ### Setup Python Path
#
# So that we could use rospy, rosbag etc in the notebook.

# %%
#@title setup python path {display-mode: "form"}
import sys
import os

sys.path.append('/opt/ros/melodic/lib/python2.7/dist-packages/')
print(sys.path)

os.environ['PATH'] += ':/opt/ros/melodic/bin'
print(os.environ['PATH'])
# Out:
# ['', '/content', '/env/python', '/usr/lib/python37.zip', '/usr/lib/python3.7', '/usr/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.7/dist-packages/IPython/extensions', '/root/.ipython', '/opt/ros/melodic/lib/python2.7/dist-packages/']
# /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/opt/ros/melodic/bin

# %% [markdown]
# ## A. ROS System and Processes

# %% [markdown]
# ### roscore

# %% [markdown]
# **roscore** is a collection of nodes and programs that are pre-requisites of a ROS-based system. You must have a roscore running in order for ROS nodes to communicate. It is launched using the roscore command.
#
# NOTE: If you use roslaunch, it will automatically start roscore if it detects that it is not already running (unless the --wait argument is supplied).
#
# **roscor** will start up:
#
# * a ROS Master
#
# * a ROS Parameter Server
#
# * a rosout logging node

# %%
import time

# %%
get_ipython().system_raw('source /opt/ros/melodic/setup.bash && roscore &')
time.sleep(3)

# %% [markdown]
# ### rosnode

# %% [markdown]
# A ROS **node**, according to ROS wiki, is basically a process that performs computation. It is an executable program running inside your application. You will write many nodes and put them into packages.
#
# Nodes are combined into a graph and communicate with each other using ROS topics, services, actions, etc.
#
# Note that 2 nodes can’t have the same name. If you want to run multiple instances of the same node, you’ll have to add a prefix or suffix to the name, or declare them as anonymous.

# %%
# !source /opt/ros/melodic/setup.bash && rosnode list
# Out:
# /rosout

# %% [markdown]
# ### Manage Processes
#
# We could check all ROS related processes.

# %%
# !ps ax | grep ros
# Out:
#    4621 ?        S      0:00 /bin/bash -c source /opt/ros/melodic/setup.bash && roscore &
#    4646 ?        Sl     0:00 /usr/bin/python /opt/ros/melodic/bin/roscore
#    4664 ?        Ssl    0:00 /usr/bin/python /opt/ros/melodic/bin/rosmaster --core -p 11311 -w 3 __log:=/root/.ros/log/edd89760-9702-11ec-90fd-0242ac1c0002/master.log
#    4676 ?        Ssl    0:00 /opt/ros/melodic/lib/rosout/rosout __name:=rosout __log:=/root/.ros/log/edd89760-9702-11ec-90fd-0242ac1c0002/rosout-1.log
#    4723 ?        S      0:00 /bin/bash -c ps ax | grep ros
#    4725 ?        S      0:00 grep ros

# %% [markdown]
# We could kill the roscore and hello node process when you see it working.

# %%
# !kill 4982
# Out:
# /bin/bash: line 0: kill: (4982) - No such process

# %%
# !ps ax | grep ros
# Out:
#    4621 ?        S      0:00 /bin/bash -c source /opt/ros/melodic/setup.bash && roscore &
#    4646 ?        Sl     0:00 /usr/bin/python /opt/ros/melodic/bin/roscore
#    4664 ?        Ssl    0:00 /usr/bin/python /opt/ros/melodic/bin/rosmaster --core -p 11311 -w 3 __log:=/root/.ros/log/edd89760-9702-11ec-90fd-0242ac1c0002/master.log
#    4676 ?        Ssl    0:00 /opt/ros/melodic/lib/rosout/rosout __name:=rosout __log:=/root/.ros/log/edd89760-9702-11ec-90fd-0242ac1c0002/rosout-1.log
#    4727 ?        S      0:00 /bin/bash -c ps ax | grep ros
#    4729 ?        S      0:00 grep ros

# %% [markdown]
# ## B. ROS Built-in Messages
#
# Standard ROS Messages including common message types representing primitive data types and other basic message constructs, such as:
# * [std_msgs](http://wiki.ros.org/std_msgs)
# * [geometry_msgs](http://wiki.ros.org/geometry_msgs).
# * [common_msgs](https://wiki.ros.org/common_msgs).
# * More...

# %%
# !ls /opt/ros/melodic/lib/python2.7/dist-packages/*_msgs
# Out:
# /opt/ros/melodic/lib/python2.7/dist-packages/actionlib_msgs:
# __init__.py  __init__.pyc  msg
#
# /opt/ros/melodic/lib/python2.7/dist-packages/diagnostic_msgs:
# __init__.py  __init__.pyc  msg	srv
#
# /opt/ros/melodic/lib/python2.7/dist-packages/geometry_msgs:
# __init__.py  __init__.pyc  msg
#
# /opt/ros/melodic/lib/python2.7/dist-packages/nav_msgs:
# __init__.py  __init__.pyc  msg	srv
#
# /opt/ros/melodic/lib/python2.7/dist-packages/rosgraph_msgs:
# __init__.py  __init__.pyc  msg
#
# /opt/ros/melodic/lib/python2.7/dist-packages/sensor_msgs:
# __init__.py  __init__.pyc  msg	point_cloud2.py  point_cloud2.pyc  srv
#
# /opt/ros/melodic/lib/python2.7/dist-packages/shape_msgs:
# __init__.py  __init__.pyc  msg
#
# /opt/ros/melodic/lib/python2.7/dist-packages/std_msgs:
# __init__.py  __init__.pyc  msg
#
# /opt/ros/melodic/lib/python2.7/dist-packages/stereo_msgs:
# __init__.py  __init__.pyc  msg
#
# /opt/ros/melodic/lib/python2.7/dist-packages/trajectory_msgs:
# __init__.py  __init__.pyc  msg
#
# /opt/ros/melodic/lib/python2.7/dist-packages/visualization_msgs:
# __init__.py  __init__.pyc  msg

# %%
# !ls /opt/ros/melodic/lib/python2.7/dist-packages/std_msgs/msg
# Out:
# _Bool.py		_Header.py		  _MultiArrayLayout.py
# _Bool.pyc		_Header.pyc		  _MultiArrayLayout.pyc
# _ByteMultiArray.py	__init__.py		  _String.py
# _ByteMultiArray.pyc	__init__.pyc		  _String.pyc
# _Byte.py		_Int16MultiArray.py	  _Time.py
# _Byte.pyc		_Int16MultiArray.pyc	  _Time.pyc
# _Char.py		_Int16.py		  _UInt16MultiArray.py
# _Char.pyc		_Int16.pyc		  _UInt16MultiArray.pyc
# _ColorRGBA.py		_Int32MultiArray.py	  _UInt16.py
# _ColorRGBA.pyc		_Int32MultiArray.pyc	  _UInt16.pyc
# _Duration.py		_Int32.py		  _UInt32MultiArray.py
# _Duration.pyc		_Int32.pyc		  _UInt32MultiArray.pyc
# _Empty.py		_Int64MultiArray.py	  _UInt32.py
# _Empty.pyc		_Int64MultiArray.pyc	  _UInt32.pyc
# _Float32MultiArray.py	_Int64.py		  _UInt64MultiArray.py
# _Float32MultiArray.pyc	_Int64.pyc		  _UInt64MultiArray.pyc
# _Float32.py		_Int8MultiArray.py	  _UInt64.py
# _Float32.pyc		_Int8MultiArray.pyc	  _UInt64.pyc
# _Float64MultiArray.py	_Int8.py		  _UInt8MultiArray.py
# _Float64MultiArray.pyc	_Int8.pyc		  _UInt8MultiArray.pyc
# _Float64.py		_MultiArrayDimension.py   _UInt8.py
# _Float64.pyc		_MultiArrayDimension.pyc  _UInt8.pyc

# %%
# !ls /opt/ros/melodic/lib/python2.7/dist-packages/geometry_msgs/msg
# Out:
# _Accel.py			 _PoseStamped.py
# _Accel.pyc			 _PoseStamped.pyc
# _AccelStamped.py		 _PoseWithCovariance.py
# _AccelStamped.pyc		 _PoseWithCovariance.pyc
# _AccelWithCovariance.py		 _PoseWithCovarianceStamped.py
# _AccelWithCovariance.pyc	 _PoseWithCovarianceStamped.pyc
# _AccelWithCovarianceStamped.py	 _Quaternion.py
# _AccelWithCovarianceStamped.pyc  _Quaternion.pyc
# _Inertia.py			 _QuaternionStamped.py
# _Inertia.pyc			 _QuaternionStamped.pyc
# _InertiaStamped.py		 _Transform.py
# _InertiaStamped.pyc		 _Transform.pyc
# __init__.py			 _TransformStamped.py
# __init__.pyc			 _TransformStamped.pyc
# _Point32.py			 _Twist.py
# _Point32.pyc			 _Twist.pyc
# _Point.py			 _TwistStamped.py
# _Point.pyc			 _TwistStamped.pyc
# _PointStamped.py		 _TwistWithCovariance.py
# _PointStamped.pyc		 _TwistWithCovariance.pyc
# _Polygon.py			 _TwistWithCovarianceStamped.py
# _Polygon.pyc			 _TwistWithCovarianceStamped.pyc
# _PolygonStamped.py		 _Vector3.py
# _PolygonStamped.pyc		 _Vector3.pyc
# _Pose2D.py			 _Vector3Stamped.py
# _Pose2D.pyc			 _Vector3Stamped.pyc
# _PoseArray.py			 _Wrench.py
# _PoseArray.pyc			 _Wrench.pyc
# _Pose.py			 _WrenchStamped.py
# _Pose.pyc			 _WrenchStamped.pyc

# %% [markdown]
# ## C. ROS Publisher

# %% [markdown]
# ### 1. Start a roscore
#
# **roscore** is a collection of nodes and programs that are pre-requisites of a ROS-based system. You must have a roscore running in order for ROS nodes to communicate. It is launched using the roscore command.

# %%
# !source /opt/ros/melodic/setup.bash && rostopic list
# Out:
# /rosout
# /rosout_agg

# %% [markdown]
# ### 2. Our first publisher (only publish once)
#
# Let's write a simple publisher, and publish "hello world" once.

# %%
import rospy
from std_msgs.msg import String

pub = rospy.Publisher('topic_name', String, queue_size=10)
rospy.init_node('node_name')
pub.publish("hello world")
# Out:
# WARNING: cannot load logging configuration file, logging is disabled

# %%
# !source /opt/ros/melodic/setup.bash && rostopic list
# Out:
# /rosout
# /rosout_agg
# /topic_name

# %% [markdown]
# ### publish std_msgs and geometry_msgs

# %% [markdown]
# Let's see a simple publisher, and publish the messages with the types of ***std_msgs*** and ***geometry_msgs***.

# %%
# %%writefile talker.py
import rospy
from std_msgs.msg import String
from geometry_msgs.msg import Twist

pub = rospy.Publisher('greeting', String, queue_size=10)
pub_cmd = rospy.Publisher('commands', Twist, queue_size=10)
  
rospy.init_node('talker')
rate = rospy.Rate(10) # 10hz

cmd_msg = Twist()
cmd_msg.linear.x = 1
cmd_msg.linear.y = 0
cmd_msg.linear.z = 0
cmd_msg.angular.x = 0
cmd_msg.angular.y = 0
cmd_msg.angular.z = 2

while not rospy.is_shutdown():
  hello_str = "hello world"
  pub.publish(hello_str)
  pub_cmd.publish(cmd_msg)

  rate.sleep()
# Out:
# Writing talker.py

# %%
get_ipython().system_raw('source /opt/ros/melodic/setup.bash && python talker.py & ')
time.sleep(3)

# %%
# !source /opt/ros/melodic/setup.bash && rostopic list
# Out:
# /commands
# /greeting
# /rosout
# /rosout_agg
# /topic_name

# %%
# !source /opt/ros/melodic/setup.bash && rosnode list
# Out:
# /node_name
# /rosout
# /talker

# %% [markdown]
# ### rostopic
#
# We could use rostopic tool to display publisher and subscriber.

# %%
# !source /opt/ros/melodic/setup.bash && rostopic info /greeting
# !source /opt/ros/melodic/setup.bash && rostopic info /commands
# Out:
# Type: std_msgs/String
#
# Publishers:
#  * /talker (http://577ae0c7c210:39597/)
#
# Subscribers: None
#
#
# Type: geometry_msgs/Twist
#
# Publishers:
#  * /talker (http://577ae0c7c210:39597/)
#
# Subscribers: None

# %% [markdown]
# Nevertheless, rostopic echo will keep showing the message. We just echo once (-n 1). Stop the cells may also stop the publishers in Colab. We will use it more often in laptop terminals.

# %% [markdown]
# ### Exercise Part A (1 point)
#
# Free point! Just let you know how this works!

# %%
# !source /opt/ros/melodic/setup.bash && rostopic echo -n 1 /greeting > ex1a_out.txt
file = open("ex1a_out.txt")
ex1a_out = file.read().replace("\n", " ")
file.close()
print(ex1a_out)
assert ex1a_out == 'data: "hello world" --- '

# !source /opt/ros/melodic/setup.bash && rostopic echo -n 1 /commands > ex1b_out.txt
file = open("ex1b_out.txt")
ex1b_out = file.read().replace("\n", " ")
file.close()
print(ex1b_out)
assert ex1b_out == 'linear:    x: 1.0   y: 0.0   z: 0.0 angular:    x: 0.0   y: 0.0   z: 2.0 --- '
# Out:
# data: "hello world" ---
# linear:    x: 1.0   y: 0.0   z: 0.0 angular:    x: 0.0   y: 0.0   z: 2.0 ---

# %% [markdown]
# You could check the running process, such as roscore and talker.py, and make sure they are still running.

# %%
# !ps ax | grep ros
# Out:
#    4621 ?        S      0:00 /bin/bash -c source /opt/ros/melodic/setup.bash && roscore &
#    4646 ?        Sl     0:00 /usr/bin/python /opt/ros/melodic/bin/roscore
#    4664 ?        Ssl    0:00 /usr/bin/python /opt/ros/melodic/bin/rosmaster --core -p 11311 -w 3 __log:=/root/.ros/log/edd89760-9702-11ec-90fd-0242ac1c0002/master.log
#    4676 ?        Ssl    0:00 /opt/ros/melodic/lib/rosout/rosout __name:=rosout __log:=/root/.ros/log/edd89760-9702-11ec-90fd-0242ac1c0002/rosout-1.log
#    4799 ?        S      0:00 /bin/bash -c source /opt/ros/melodic/setup.bash && python talker.py &
#    5044 ?        S      0:00 /bin/bash -c ps ax | grep ros
#    5046 ?        S      0:00 grep ros

# %% [markdown]
# ### Exercise Part B (1 point)
#
# Please write a simple publisher node "my_node", and publish with the topic "my_topic", and output "my first publisher" in the background.

# %%
# %%writefile hello.py
import rospy
from std_msgs.msg import String

# YOUR CODE HERE
pub = rospy.Publisher("my_topic", String, queue_size=10)

rospy.init_node('my_node')

rate = rospy.Rate(10) # 10hz

while not rospy.is_shutdown():
  output_string = "my first publisher"
  pub.publish(output_string)

  rate.sleep()
# raise NotImplementedError()
# Out:
# Writing hello.py

# %%
get_ipython().system_raw('source /opt/ros/melodic/setup.bash && python hello.py & ')
time.sleep(3)

# %% [markdown]
# We will write the output to a text file, and then read it for test.

# %%
# !source /opt/ros/melodic/setup.bash && rostopic echo -n 1 /my_topic > ex2_out.txt
file = open("ex2_out.txt")
ex2_out = file.read().replace("\n", " ")
file.close()

assert ex2_out == 'data: "my first publisher" --- '

# %% [markdown]
# ##  D. Subscriber
# Let's write a simple subscriber to get the messages from the publisher.
#
# spin() simply keeps python from exiting until this node is stopped

# %%
# %%writefile listener.py

import sys
import rospy
from std_msgs.msg import String

def callback(data):
  rospy.loginfo(rospy.get_caller_id() + "I heard %s", data.data)

def main(args):
  rospy.init_node('listener')
  rospy.Subscriber("greeting", String, callback)
  rospy.spin()

if __name__ == '__main__':
  main(sys.argv)
# Out:
# Writing listener.py

# %% [markdown]
# ### Running the subscriber in background

# %% [markdown]
# Let's run the subscriber and let it spin.
# Nevertheless, you don't get to see "I heard ..." here because the subscriber is running in the background.
# Don't worry we will get to this later in the class.

# %%
get_ipython().system_raw('source /opt/ros/melodic/setup.bash && python listener.py & ')
time.sleep(3)

# %% [markdown]
# ### Check with rostopic info

# %% [markdown]
# Now you could see /greeting has both Publisher and Subscriber.

# %%
# !source /opt/ros/melodic/setup.bash && rostopic info /greeting
# !source /opt/ros/melodic/setup.bash && rostopic info /commands
# Out:
# Type: std_msgs/String
#
# Publishers:
#  * /talker (http://577ae0c7c210:39597/)
#
# Subscribers:
#  * /listener (http://577ae0c7c210:39311/)
#
#
# Type: geometry_msgs/Twist
#
# Publishers:
#  * /talker (http://577ae0c7c210:39597/)
#
# Subscribers: None
