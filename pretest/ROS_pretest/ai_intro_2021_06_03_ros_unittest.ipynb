# %% [markdown]
# # ROS and Unit Test
#
# The ROS unittest example was from the Duckietown materials.

# %% [markdown]
# ## Installation and Setup

# %% [markdown]
# ### Install ROS
#
# We will use ROS melodic with Python 2

# %%
# %%bash
# sh -c 'echo "deb http://packages.ros.org/ros/ubuntu $(lsb_release -sc) main" > /etc/apt/sources.list.d/ros-latest.list'
# apt-key adv --keyserver 'hkp://keyserver.ubuntu.com:80' --recv-key C1CF6E31E6BADE8868B172B4F42ED6FBAB17C654
# apt update  &> /dev/null
# apt install ros-melodic-ros-base &> /dev/null
#
# sudo rosdep init  &> /dev/null
# rosdep update  &> /dev/null
#
# apt install python-rosinstall  &> /dev/null
# apt install python-catkin-tools  &> /dev/null
# apt install ros-melodic-ros-numpy ros-melodic-vision-opencv &> /dev/null
# Out:
# Executing: /tmp/apt-key-gpghome.p3URytLwJ8/gpg.1.sh --keyserver hkp://keyserver.ubuntu.com:80 --recv-key C1CF6E31E6BADE8868B172B4F42ED6FBAB17C654
# Warning: apt-key output should not be parsed (stdout is not a terminal)
# gpg: key F42ED6FBAB17C654: public key "Open Robotics <info@osrfoundation.org>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1

# %%
# !sudo apt-get install libeigen3-dev ros-melodic-theora-image-transport ros-melodic-image-publisher
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libeigen3-dev is already the newest version (3.3.4-4).
# ros-melodic-image-publisher is already the newest version (1.15.0-1bionic.20210921.211325).
# ros-melodic-theora-image-transport is already the newest version (1.9.5-0bionic.20210921.211317).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-470
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 64 not upgraded.

# %% [markdown]
# ### Setup Python Path
#
# So that we could use rospy, rosbag etc in the notebook.

# %%
import sys
import os

sys.path.append('/opt/ros/melodic/lib/python2.7/dist-packages/')
print(sys.path)

os.environ['PATH'] += ':/opt/ros/melodic/bin'
print(os.environ['PATH'])
# Out:
# ['', '/content', '/env/python', '/usr/lib/python37.zip', '/usr/lib/python3.7', '/usr/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.7/dist-packages/IPython/extensions', '/root/.ipython', '/opt/ros/melodic/lib/python2.7/dist-packages/', '/opt/ros/melodic/lib/python2.7/dist-packages/']
# /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/opt/ros/melodic/bin:/opt/ros/melodic/bin

# %% [markdown]
# ### Create a workspace

# %%
# !mkdir -p /content/catkin_ws/src

# %% [markdown]
# ## Get Ready the AprilTags Repos

# %% [markdown]
# ### apriltags_ros
#
# We will use the ROS package, widely used in the robotics community. There are two ROS packages:
# * apriltags: the C++ code as library
# * apriltags_ros: also C++ with ROS publisher and subscriber.
#
# General Info about April Tags https://april.eecs.umich.edu/wiki/AprilTags

# %%
# %cd /content/catkin_ws/src
# !git clone https://github.com/Sensing-Intelligent-System/apriltags_ros.git
# Out:
# /content/catkin_ws/src
# fatal: destination path 'apriltags_ros' already exists and is not an empty directory.

# %% [markdown]
# ### apriltags_ros_test
#
# We will use another repo, originally located in the Duckietown repo.

# %%
# %cd /content/catkin_ws/src
# !git clone https://github.com/Sensing-Intelligent-System/apriltags_ros_test.git
# Out:
# /content/catkin_ws/src
# fatal: destination path 'apriltags_ros_test' already exists and is not an empty directory.

# %% [markdown]
# ### catkin_make
#
# Now we have two ROS packages under src/. Let's compile with catkin_make

# %%
# %cd /content/catkin_ws
# !source /opt/ros/melodic/setup.bash && catkin_make
# Out:
# /content/catkin_ws
# Base path: /content/catkin_ws
# Source space: /content/catkin_ws/src
# Build space: /content/catkin_ws/build
# Devel space: /content/catkin_ws/devel
# Install space: /content/catkin_ws/install
# ####
# #### Running command: "make cmake_check_build_system" in "/content/catkin_ws/build"
# ####
# ####
# #### Running command: "make -j2 -l2" in "/content/catkin_ws/build"
# ####
# [ 45%] Built target apriltags
# [ 45%] Built target _apriltags_ros_generate_messages_check_deps_AprilTagDetectionArray
# [ 45%] Built target std_msgs_generate_messages_cpp
# [ 45%] Built target geometry_msgs_generate_messages_cpp
# [ 45%] Built target std_msgs_generate_messages_eus
# [ 45%] Built target geometry_msgs_generate_messages_eus
# [ 45%] Built target _apriltags_ros_generate_messages_check_deps_AprilTagDetection
# [ 45%] Built target std_msgs_generate_messages_py
# [ 45%] Built target geometry_msgs_generate_messages_py
# [ 45%] Built target std_msgs_generate_messages_nodejs
# [ 45%] Built target geometry_msgs_generate_messages_nodejs
# [ 45%] Built target std_msgs_generate_messages_lisp
# [ 45%] Built target geometry_msgs_generate_messages_lisp
# [ 57%] Built target apriltags_ros_generate_messages_cpp
# [ 60%] Built target apriltags_ros_generate_messages_eus
# [ 69%] Built target apriltags_ros_generate_messages_py
# [ 75%] Built target apriltags_ros_generate_messages_nodejs
# [ 81%] Built target apriltags_ros_generate_messages_lisp
# [ 87%] Built target apriltag_detector
# [ 87%] Built target apriltags_ros_generate_messages
# [ 93%] Built target apriltag_detector_node
# [100%] Built target apriltag_detector_nodelet

# %% [markdown]
# ## ROS Test

# %% [markdown]
# ### The tests folder
#
# In the tests filder, again you could see a pair of tester_node (.py and .test). You could also find two images files, which will be loaded during testing.

# %%
# !ls /content/catkin_ws/src/apriltags_ros_test/tests
# Out:
# 20160508-apriltag108-starducks.png  apriltags_tester_node.py
# 20210315-apriltag163-stop.jpg	    apriltags_tester_node.test

# %% [markdown]
# ### apriltags_tester_node.py

# %%
# !cat /content/catkin_ws/src/apriltags_ros_test/tests/apriltags_tester_node.py
# Out:
# #!/usr/bin/env python
# import rospy
# import unittest
# import rostest
# from apriltags_ros.msg import AprilTagDetectionArray
# from sensor_msgs.msg import CameraInfo, Image
# from cv_bridge import CvBridge
# import cv2
# from tf import transformations as tr
# import numpy as np
#
# class ApriltagsTesterNode(unittest.TestCase):
#     def setup(self):
#         # Setup the node
#         rospy.init_node('apriltags_tester_node', anonymous=False)
#         self.msg_received = False
#         self.msg_tags = AprilTagDetectionArray()
#
#         # Setup the publisher and subscriber
#         self.pub_raw  = rospy.Publisher("~image_rect", Image, queue_size=1, latch=True)
#         self.pub_info  = rospy.Publisher("~camera_info", CameraInfo, queue_size=1, latch=True)
#         self.sub_tag = rospy.Subscriber( "~apriltags", AprilTagDetectionArray, self.tagCallback)
#
#         # Wait for the node  to finish starting up
#         timeout = rospy.Time.now() + rospy.Duration(5) # Wait at most 5 seconds for the node to come up
#         while (self.pub_raw.get_num_connections() < 1 or self.pub_info.get_num_connections() < 1 or
#                 self.sub_tag.get_num_connections() < 1) and not rospy.is_shutdown() and rospy.Time.now() < timeout:
#             rospy.sleep(0.1)
#
#     def tagCallback(self, msg_tags):
#         self.msg_tags = msg_tags
#         self.msg_received = True
#
#     def test_publisher_and_subscriber(self):
#         self.setup()    # Setup the node
#         self.assertGreaterEqual(self.pub_raw.get_num_connections(), 1, "No connections found on image_raw topic")
#         self.assertGreaterEqual(self.pub_info.get_num_connections(), 1, "No connections found on camera_info topic")
#         self.assertGreaterEqual(self.sub_tag.get_num_connections(), 1, "No connections found on apriltags topic")
#
#     def test_with_known_image(self):
#         filename = rospy.get_param("~filename")
#         self.setup()    # Setup the node
#
#         # Publish the camera info
#         msg_info = CameraInfo()
#         msg_info.height = 480
#         msg_info.width = 640
#         msg_info.K = [331.026328, 0.0, 319.035097, 0.0, 335.330339, 216.450133, 0.0, 0.0, 1.0]
#         self.pub_info.publish(msg_info)
#
#         # Publish the test image
#         img = cv2.imread(filename)
#         cvb = CvBridge()
#         msg_raw = cvb.cv2_to_imgmsg(img, encoding="bgr8")
#         self.pub_raw.publish(msg_raw)
#
#         # Wait for the message to be received
#         timeout = rospy.Time.now() + rospy.Duration(5) # Wait at most 5 seconds for the node to reply
#         while not self.msg_received and not rospy.is_shutdown() and rospy.Time.now() < timeout:
#             rospy.sleep(0.1)
#         self.assertLess(rospy.Time.now(), timeout, "Waiting for apriltag detection timed out.")
#
#         # Check that an apriltag with id=108 was detected
#         found = 0
#         for tag in self.msg_tags.detections:
#             if tag.id == 108:
#                 found +=1
#                 self.assertAlmostEqual(tag.pose.pose.position.x, 0.0, delta=0.1) # Allow 10 cm of error margin
#                 self.assertAlmostEqual(tag.pose.pose.position.y, 0.0, delta=0.1) # Allow 10 cm of error margin
#                 self.assertAlmostEqual(tag.pose.pose.position.z, 0.46, delta=0.1) # Allow 10 cm of error margin
#                 # Convert the quat to an angle about z
#                 rot = tag.pose.pose.orientation
#                 ang = tr.euler_from_quaternion((rot.x, rot.y, rot.z, rot.w))[2] #z axis angle only
#                 self.assertAlmostEqual(ang, 0, delta=15*np.pi/180) # Allow up to 15 degrees of error margin
#
#         self.assertGreaterEqual(found,1, "Expected apriltag with id=108 not found.")
#
#
#
# if __name__ == '__main__':
#     rostest.rosrun('apriltags', 'apriltags_tester_node', ApriltagsTesterNode)

# %% [markdown]
# ### apriltags_tester_node.test

# %%
# !cat /content/catkin_ws/src/apriltags_ros_test/tests/apriltags_tester_node.test
# Out:
# <launch>
#     <arg name="pkg_name" value="apriltags_ros"/>
#     <arg name="node_name" default="apriltags_tester_node"/>
#
#     <arg name="veh" default="testbot" doc="Name of vehicle. ex: megaman"/>
#     <!--<arg name="filename" default="$(find apriltags_ros_test)/tests/20160408-226-intersection_apriltags_24_60-amadobot.png" />-->
#     <arg name="filename" default="$(find apriltags_ros_test)/tests/20160508-apriltag108-starducks.png" />
#     <!--<arg name="filename" default="$(find apriltags_ros_test)/tests/20210315-apriltag163-stop.jpg" />-->
#
#     <!-- Run the node -->
#     <include file="$(find apriltags_ros_test)/launch/apriltag_detector_node.launch">
#         <arg name="veh" value="$(arg veh)"/>
#     </include>
#
#     <!-- Run unit test -->
#     <remap from="apriltags_tester_node/image_rect" to="image_rect" />
#     <remap from="apriltags_tester_node/camera_info" to="camera_info" />
#     <remap from="apriltags_tester_node/apriltags" to="tag_detections" />
#     <test test-name="apriltags_tester_node" pkg="apriltags_ros_test" type="apriltags_tester_node.py" ns="$(arg veh)">
#         <param name="filename" value="$(arg filename)" />
#     </test>
# </launch>

# %% [markdown]
# ### Run rostest

# %% [markdown]
# Run rostest for apriltags_ros_test apriltags_tester_node.test

# %%
# !source /content/catkin_ws/devel/setup.bash && rostest apriltags_ros_test apriltags_tester_node.test
# Out:
# ... logging to /root/.ros/log/rostest-166ed9e33119-9016.log
# [ROSUNIT] Outputting test results to /root/.ros/test_results/apriltags_ros_test/rostest-tests_apriltags_tester_node.xml
# [ INFO] [1645880466.360412285]: Loaded tag config: 1, size: 0.065, frame_name: viewed_tag_1
# [ INFO] [1645880466.363685635]: Loaded tag config: 2, size: 0.065, frame_name: viewed_tag_2
# [ INFO] [1645880466.363935349]: Loaded tag config: 3, size: 0.065, frame_name: viewed_tag_3
# [ INFO] [1645880466.364006595]: Loaded tag config: 4, size: 0.065, frame_name: viewed_tag_4
# [ INFO] [1645880466.364071643]: Loaded tag config: 5, size: 0.065, frame_name: viewed_tag_5
# [ INFO] [1645880466.364133534]: Loaded tag config: 6, size: 0.065, frame_name: viewed_tag_6
# [ INFO] [1645880466.364187739]: Loaded tag config: 7, size: 0.065, frame_name: viewed_tag_7
# [ INFO] [1645880466.364240571]: Loaded tag config: 8, size: 0.065, frame_name: viewed_tag_8
# [ INFO] [1645880466.364294389]: Loaded tag config: 9, size: 0.065, frame_name: viewed_tag_9
# [ INFO] [1645880466.364348632]: Loaded tag config: 10, size: 0.065, frame_name: viewed_tag_10
# [ INFO] [1645880466.364403518]: Loaded tag config: 11, size: 0.065, frame_name: viewed_tag_11
# [ INFO] [1645880466.364457430]: Loaded tag config: 12, size: 0.065, frame_name: viewed_tag_12
# [ INFO] [1645880466.364510496]: Loaded tag config: 13, size: 0.065, frame_name: viewed_tag_13
# [ INFO] [1645880466.364566533]: Loaded tag config: 14, size: 0.065, frame_name: viewed_tag_14
# [ INFO] [1645880466.364617238]: Loaded tag config: 15, size: 0.065, frame_name: viewed_tag_15
# [ INFO] [1645880466.364670235]: Loaded tag config: 16, size: 0.065, frame_name: viewed_tag_16
# [ INFO] [1645880466.364723669]: Loaded tag config: 17, size: 0.065, frame_name: viewed_tag_17
# [ INFO] [1645880466.364776870]: Loaded tag config: 18, size: 0.065, frame_name: viewed_tag_18
# [ INFO] [1645880466.364829822]: Loaded tag config: 19, size: 0.065, frame_name: viewed_tag_19
# [ INFO] [1645880466.364888579]: Loaded tag config: 20, size: 0.065, frame_name: viewed_tag_20
# [ INFO] [1645880466.364964990]: Loaded tag config: 21, size: 0.065, frame_name: viewed_tag_21
# [ INFO] [1645880466.365019805]: Loaded tag config: 22, size: 0.065, frame_name: viewed_tag_22
# [ INFO] [1645880466.365074926]: Loaded tag config: 23, size: 0.065, frame_name: viewed_tag_23
# [ INFO] [1645880466.365130605]: Loaded tag config: 24, size: 0.065, frame_name: viewed_tag_24
# [ INFO] [1645880466.365184174]: Loaded tag config: 25, size: 0.065, frame_name: viewed_tag_25
# [ INFO] [1645880466.365237412]: Loaded tag config: 26, size: 0.065, frame_name: viewed_tag_26
# [ INFO] [1645880466.365291599]: Loaded tag config: 27, size: 0.065, frame_name: viewed_tag_27
# [ INFO] [1645880466.365346341]: Loaded tag config: 28, size: 0.065, frame_name: viewed_tag_28
# [ INFO] [1645880466.365399495]: Loaded tag config: 29, size: 0.065, frame_name: viewed_tag_29
# [ INFO] [1645880466.365452059]: Loaded tag config: 30, size: 0.065, frame_name: viewed_tag_30
# [ INFO] [1645880466.365504120]: Loaded tag config: 31, size: 0.065, frame_name: viewed_tag_31
# [ INFO] [1645880466.365562091]: Loaded tag config: 32, size: 0.065, frame_name: viewed_tag_32
# [ INFO] [1645880466.365621194]: Loaded tag config: 33, size: 0.065, frame_name: viewed_tag_33
# [ INFO] [1645880466.365674065]: Loaded tag config: 34, size: 0.065, frame_name: viewed_tag_34
# [ INFO] [1645880466.365728403]: Loaded tag config: 35, size: 0.065, frame_name: viewed_tag_35
# [ INFO] [1645880466.365780871]: Loaded tag config: 36, size: 0.065, frame_name: viewed_tag_36
# [ INFO] [1645880466.365833417]: Loaded tag config: 37, size: 0.065, frame_name: viewed_tag_37
# [ INFO] [1645880466.365886193]: Loaded tag config: 38, size: 0.065, frame_name: viewed_tag_38
# [ INFO] [1645880466.365951163]: Loaded tag config: 39, size: 0.065, frame_name: viewed_tag_39
# [ INFO] [1645880466.366005849]: Loaded tag config: 40, size: 0.065, frame_name: viewed_tag_40
# [ INFO] [1645880466.366060412]: Loaded tag config: 41, size: 0.065, frame_name: viewed_tag_41
# [ INFO] [1645880466.366114591]: Loaded tag config: 42, size: 0.065, frame_name: viewed_tag_42
# [ INFO] [1645880466.366168847]: Loaded tag config: 43, size: 0.065, frame_name: viewed_tag_43
# [ INFO] [1645880466.366222353]: Loaded tag config: 44, size: 0.065, frame_name: viewed_tag_44
# [ INFO] [1645880466.366276447]: Loaded tag config: 45, size: 0.065, frame_name: viewed_tag_45
# [ INFO] [1645880466.366329269]: Loaded tag config: 46, size: 0.065, frame_name: viewed_tag_46
# [ INFO] [1645880466.366381953]: Loaded tag config: 47, size: 0.065, frame_name: viewed_tag_47
# [ INFO] [1645880466.366435094]: Loaded tag config: 48, size: 0.065, frame_name: viewed_tag_48
# [ INFO] [1645880466.366488018]: Loaded tag config: 49, size: 0.065, frame_name: viewed_tag_49
# [ INFO] [1645880466.366547641]: Loaded tag config: 50, size: 0.065, frame_name: viewed_tag_50
# [ INFO] [1645880466.366608335]: Loaded tag config: 51, size: 0.065, frame_name: viewed_tag_51
# [ INFO] [1645880466.366665862]: Loaded tag config: 52, size: 0.065, frame_name: viewed_tag_52
# [ INFO] [1645880466.366720520]: Loaded tag config: 53, size: 0.065, frame_name: viewed_tag_53
# [ INFO] [1645880466.366772807]: Loaded tag config: 54, size: 0.065, frame_name: viewed_tag_54
# [ INFO] [1645880466.366826118]: Loaded tag config: 55, size: 0.065, frame_name: viewed_tag_55
# [ INFO] [1645880466.366885101]: Loaded tag config: 56, size: 0.065, frame_name: viewed_tag_56
# [ INFO] [1645880466.366957774]: Loaded tag config: 57, size: 0.065, frame_name: viewed_tag_57
# [ INFO] [1645880466.367011392]: Loaded tag config: 58, size: 0.065, frame_name: viewed_tag_58
# [ INFO] [1645880466.367064150]: Loaded tag config: 59, size: 0.065, frame_name: viewed_tag_59
# [ INFO] [1645880466.367119638]: Loaded tag config: 60, size: 0.065, frame_name: viewed_tag_60
# [ INFO] [1645880466.367172929]: Loaded tag config: 61, size: 0.065, frame_name: viewed_tag_61
# [ INFO] [1645880466.367227066]: Loaded tag config: 62, size: 0.065, frame_name: viewed_tag_62
# [ INFO] [1645880466.367281303]: Loaded tag config: 63, size: 0.065, frame_name: viewed_tag_63
# [ INFO] [1645880466.367334310]: Loaded tag config: 64, size: 0.065, frame_name: viewed_tag_64
# [ INFO] [1645880466.367387670]: Loaded tag config: 65, size: 0.065, frame_name: viewed_tag_65
# [ INFO] [1645880466.367439686]: Loaded tag config: 66, size: 0.065, frame_name: viewed_tag_66
# [ INFO] [1645880466.367491994]: Loaded tag config: 67, size: 0.065, frame_name: viewed_tag_67
# [ INFO] [1645880466.367553367]: Loaded tag config: 68, size: 0.065, frame_name: viewed_tag_68
# [ INFO] [1645880466.367616789]: Loaded tag config: 69, size: 0.065, frame_name: viewed_tag_69
# [ INFO] [1645880466.367671290]: Loaded tag config: 70, size: 0.065, frame_name: viewed_tag_70
# [ INFO] [1645880466.367724429]: Loaded tag config: 71, size: 0.065, frame_name: viewed_tag_71
# [ INFO] [1645880466.367777671]: Loaded tag config: 72, size: 0.065, frame_name: viewed_tag_72
# [ INFO] [1645880466.367830500]: Loaded tag config: 73, size: 0.065, frame_name: viewed_tag_73
# [ INFO] [1645880466.367883037]: Loaded tag config: 74, size: 0.065, frame_name: viewed_tag_74
# [ INFO] [1645880466.367939983]: Loaded tag config: 75, size: 0.065, frame_name: viewed_tag_75
# [ INFO] [1645880466.367994048]: Loaded tag config: 76, size: 0.065, frame_name: viewed_tag_76
# [ INFO] [1645880466.368048274]: Loaded tag config: 77, size: 0.065, frame_name: viewed_tag_77
# [ INFO] [1645880466.368102215]: Loaded tag config: 78, size: 0.065, frame_name: viewed_tag_78
# [ INFO] [1645880466.368156667]: Loaded tag config: 79, size: 0.065, frame_name: viewed_tag_79
# [ INFO] [1645880466.368209715]: Loaded tag config: 80, size: 0.065, frame_name: viewed_tag_80
# [ INFO] [1645880466.368264113]: Loaded tag config: 81, size: 0.065, frame_name: viewed_tag_81
# [ INFO] [1645880466.368317692]: Loaded tag config: 82, size: 0.065, frame_name: viewed_tag_82
# [ INFO] [1645880466.368371548]: Loaded tag config: 83, size: 0.065, frame_name: viewed_tag_83
# [ INFO] [1645880466.368423742]: Loaded tag config: 84, size: 0.065, frame_name: viewed_tag_84
# [ INFO] [1645880466.368479544]: Loaded tag config: 85, size: 0.065, frame_name: viewed_tag_85
# [ INFO] [1645880466.368531908]: Loaded tag config: 86, size: 0.065, frame_name: viewed_tag_86
# [ INFO] [1645880466.368585329]: Loaded tag config: 87, size: 0.065, frame_name: viewed_tag_87
# [ INFO] [1645880466.368638341]: Loaded tag config: 88, size: 0.065, frame_name: viewed_tag_88
# [ INFO] [1645880466.368691117]: Loaded tag config: 89, size: 0.065, frame_name: viewed_tag_89
# [ INFO] [1645880466.368744766]: Loaded tag config: 90, size: 0.065, frame_name: viewed_tag_90
# [ INFO] [1645880466.368798507]: Loaded tag config: 91, size: 0.065, frame_name: viewed_tag_91
# [ INFO] [1645880466.368850889]: Loaded tag config: 92, size: 0.065, frame_name: viewed_tag_92
# [ INFO] [1645880466.368910583]: Loaded tag config: 93, size: 0.065, frame_name: viewed_tag_93
# [ INFO] [1645880466.368972227]: Loaded tag config: 94, size: 0.065, frame_name: viewed_tag_94
# [ INFO] [1645880466.369027493]: Loaded tag config: 95, size: 0.065, frame_name: viewed_tag_95
# [ INFO] [1645880466.369080997]: Loaded tag config: 96, size: 0.065, frame_name: viewed_tag_96
# [ INFO] [1645880466.369134025]: Loaded tag config: 97, size: 0.065, frame_name: viewed_tag_97
# [ INFO] [1645880466.369186789]: Loaded tag config: 98, size: 0.065, frame_name: viewed_tag_98
# [ INFO] [1645880466.369240073]: Loaded tag config: 99, size: 0.065, frame_name: viewed_tag_99
# [ INFO] [1645880466.369293011]: Loaded tag config: 100, size: 0.065, frame_name: viewed_tag_100
# [ INFO] [1645880466.369346671]: Loaded tag config: 101, size: 0.065, frame_name: viewed_tag_101
# [ INFO] [1645880466.369400877]: Loaded tag config: 102, size: 0.065, frame_name: viewed_tag_102
# [ INFO] [1645880466.369454366]: Loaded tag config: 103, size: 0.065, frame_name: viewed_tag_103
# [ INFO] [1645880466.369508467]: Loaded tag config: 104, size: 0.065, frame_name: viewed_tag_104
# [ INFO] [1645880466.369565229]: Loaded tag config: 105, size: 0.065, frame_name: viewed_tag_105
# [ INFO] [1645880466.369614343]: Loaded tag config: 106, size: 0.065, frame_name: viewed_tag_106
# [ INFO] [1645880466.369667211]: Loaded tag config: 107, size: 0.065, frame_name: viewed_tag_107
# [ INFO] [1645880466.369722453]: Loaded tag config: 108, size: 0.065, frame_name: viewed_tag_108
# [ INFO] [1645880466.369775950]: Loaded tag config: 109, size: 0.065, frame_name: viewed_tag_109
# [ INFO] [1645880466.369829325]: Loaded tag config: 110, size: 0.065, frame_name: viewed_tag_110
# [ INFO] [1645880466.369885262]: Loaded tag config: 111, size: 0.065, frame_name: viewed_tag_111
# [ INFO] [1645880466.369960002]: Loaded tag config: 112, size: 0.065, frame_name: viewed_tag_112
# [ INFO] [1645880466.370013508]: Loaded tag config: 113, size: 0.065, frame_name: viewed_tag_113
# [ INFO] [1645880466.370067555]: Loaded tag config: 114, size: 0.065, frame_name: viewed_tag_114
# [ INFO] [1645880466.370121451]: Loaded tag config: 115, size: 0.065, frame_name: viewed_tag_115
# [ INFO] [1645880466.370175564]: Loaded tag config: 116, size: 0.065, frame_name: viewed_tag_116
# [ INFO] [1645880466.370229509]: Loaded tag config: 117, size: 0.065, frame_name: viewed_tag_117
# [ INFO] [1645880466.370282628]: Loaded tag config: 118, size: 0.065, frame_name: viewed_tag_118
# [ INFO] [1645880466.370334634]: Loaded tag config: 119, size: 0.065, frame_name: viewed_tag_119
# [ INFO] [1645880466.370387983]: Loaded tag config: 120, size: 0.065, frame_name: viewed_tag_120
# [ INFO] [1645880466.370441148]: Loaded tag config: 121, size: 0.065, frame_name: viewed_tag_121
# [ INFO] [1645880466.370495156]: Loaded tag config: 122, size: 0.065, frame_name: viewed_tag_122
# [ INFO] [1645880466.370553615]: Loaded tag config: 123, size: 0.065, frame_name: viewed_tag_123
# [ INFO] [1645880466.370612367]: Loaded tag config: 124, size: 0.065, frame_name: viewed_tag_124
# [ INFO] [1645880466.370664918]: Loaded tag config: 125, size: 0.065, frame_name: viewed_tag_125
# [ INFO] [1645880466.370717277]: Loaded tag config: 126, size: 0.065, frame_name: viewed_tag_126
# [ INFO] [1645880466.370768808]: Loaded tag config: 127, size: 0.065, frame_name: viewed_tag_127
# [ INFO] [1645880466.370822844]: Loaded tag config: 128, size: 0.065, frame_name: viewed_tag_128
# [ INFO] [1645880466.370875550]: Loaded tag config: 129, size: 0.065, frame_name: viewed_tag_129
# [ INFO] [1645880466.370929444]: Loaded tag config: 130, size: 0.065, frame_name: viewed_tag_130
# [ INFO] [1645880466.370984790]: Loaded tag config: 131, size: 0.065, frame_name: viewed_tag_131
# [ INFO] [1645880466.371040006]: Loaded tag config: 132, size: 0.065, frame_name: viewed_tag_132
# [ INFO] [1645880466.371093398]: Loaded tag config: 133, size: 0.065, frame_name: viewed_tag_133
# [ INFO] [1645880466.371147095]: Loaded tag config: 134, size: 0.065, frame_name: viewed_tag_134
# [ INFO] [1645880466.371219537]: Loaded tag config: 135, size: 0.065, frame_name: viewed_tag_135
# [ INFO] [1645880466.371294678]: Loaded tag config: 136, size: 0.065, frame_name: viewed_tag_136
# [ INFO] [1645880466.371348373]: Loaded tag config: 137, size: 0.065, frame_name: viewed_tag_137
# [ INFO] [1645880466.371402885]: Loaded tag config: 138, size: 0.065, frame_name: viewed_tag_138
# [ INFO] [1645880466.371455544]: Loaded tag config: 139, size: 0.065, frame_name: viewed_tag_139
# [ INFO] [1645880466.371512071]: Loaded tag config: 140, size: 0.065, frame_name: viewed_tag_140
# [ INFO] [1645880466.371565738]: Loaded tag config: 141, size: 0.065, frame_name: viewed_tag_141
# [ INFO] [1645880466.371619295]: Loaded tag config: 142, size: 0.065, frame_name: viewed_tag_142
# [ INFO] [1645880466.371672353]: Loaded tag config: 143, size: 0.065, frame_name: viewed_tag_143
# [ INFO] [1645880466.371727252]: Loaded tag config: 144, size: 0.065, frame_name: viewed_tag_144
# [ INFO] [1645880466.371779831]: Loaded tag config: 145, size: 0.065, frame_name: viewed_tag_145
# [ INFO] [1645880466.371833918]: Loaded tag config: 146, size: 0.065, frame_name: viewed_tag_146
# [ INFO] [1645880466.371887201]: Loaded tag config: 147, size: 0.065, frame_name: viewed_tag_147
# [ INFO] [1645880466.371955876]: Loaded tag config: 148, size: 0.065, frame_name: viewed_tag_148
# [ INFO] [1645880466.372010035]: Loaded tag config: 149, size: 0.065, frame_name: viewed_tag_149
# [ INFO] [1645880466.372063198]: Loaded tag config: 150, size: 0.065, frame_name: viewed_tag_150
# [ INFO] [1645880466.372116716]: Loaded tag config: 151, size: 0.065, frame_name: viewed_tag_151
# [ INFO] [1645880466.372171109]: Loaded tag config: 152, size: 0.065, frame_name: viewed_tag_152
# [ INFO] [1645880466.372223171]: Loaded tag config: 153, size: 0.065, frame_name: viewed_tag_153
# [ INFO] [1645880466.372275486]: Loaded tag config: 154, size: 0.065, frame_name: viewed_tag_154
# [ INFO] [1645880466.372329034]: Loaded tag config: 155, size: 0.065, frame_name: viewed_tag_155
# [ INFO] [1645880466.372382643]: Loaded tag config: 156, size: 0.065, frame_name: viewed_tag_156
# [ INFO] [1645880466.372435354]: Loaded tag config: 157, size: 0.065, frame_name: viewed_tag_157
# [ INFO] [1645880466.372488316]: Loaded tag config: 158, size: 0.065, frame_name: viewed_tag_158
# [ INFO] [1645880466.372553863]: Loaded tag config: 159, size: 0.065, frame_name: viewed_tag_159
# [ INFO] [1645880466.372621303]: Loaded tag config: 160, size: 0.065, frame_name: viewed_tag_160
# [ INFO] [1645880466.372674710]: Loaded tag config: 161, size: 0.065, frame_name: viewed_tag_161
# [ INFO] [1645880466.372726814]: Loaded tag config: 162, size: 0.065, frame_name: viewed_tag_162
# [ INFO] [1645880466.372779586]: Loaded tag config: 163, size: 0.065, frame_name: viewed_tag_163
# [ INFO] [1645880466.372834790]: Loaded tag config: 164, size: 0.065, frame_name: viewed_tag_164
# [ INFO] [1645880466.372888320]: Loaded tag config: 165, size: 0.065, frame_name: viewed_tag_165
# [ INFO] [1645880466.372955775]: Loaded tag config: 166, size: 0.065, frame_name: viewed_tag_166
# [ INFO] [1645880466.372998472]: Loaded tag config: 167, size: 0.065, frame_name: viewed_tag_167
# [ INFO] [1645880466.373028000]: Loaded tag config: 168, size: 0.065, frame_name: viewed_tag_168
# [ INFO] [1645880466.373055902]: Loaded tag config: 169, size: 0.065, frame_name: viewed_tag_169
# [ INFO] [1645880466.373084504]: Loaded tag config: 170, size: 0.065, frame_name: viewed_tag_170
# [ INFO] [1645880466.373111871]: Loaded tag config: 171, size: 0.065, frame_name: viewed_tag_171
# [ INFO] [1645880466.373139801]: Loaded tag config: 172, size: 0.065, frame_name: viewed_tag_172
# [ INFO] [1645880466.373167103]: Loaded tag config: 173, size: 0.065, frame_name: viewed_tag_173
# [ INFO] [1645880466.373194395]: Loaded tag config: 174, size: 0.065, frame_name: viewed_tag_174
# [ INFO] [1645880466.373221721]: Loaded tag config: 175, size: 0.065, frame_name: viewed_tag_175
# [ INFO] [1645880466.373250020]: Loaded tag config: 176, size: 0.065, frame_name: viewed_tag_176
# [ INFO] [1645880466.458387070]: Loaded tag config: 177, size: 0.065, frame_name: viewed_tag_177
# [ INFO] [1645880466.458422943]: Loaded tag config: 178, size: 0.065, frame_name: viewed_tag_178
# [ INFO] [1645880466.458447439]: Loaded tag config: 179, size: 0.065, frame_name: viewed_tag_179
# [ INFO] [1645880466.458467242]: Loaded tag config: 180, size: 0.065, frame_name: viewed_tag_180
# [ INFO] [1645880466.458489299]: Loaded tag config: 181, size: 0.065, frame_name: viewed_tag_181
# [ INFO] [1645880466.458510270]: Loaded tag config: 182, size: 0.065, frame_name: viewed_tag_182
# [ INFO] [1645880466.458531049]: Loaded tag config: 183, size: 0.065, frame_name: viewed_tag_183
# [ INFO] [1645880466.458571697]: Loaded tag config: 184, size: 0.065, frame_name: viewed_tag_184
# [ INFO] [1645880466.458591544]: Loaded tag config: 185, size: 0.065, frame_name: viewed_tag_185
# [ INFO] [1645880466.458611642]: Loaded tag config: 186, size: 0.065, frame_name: viewed_tag_186
# [ INFO] [1645880466.458631655]: Loaded tag config: 187, size: 0.065, frame_name: viewed_tag_187
# [ INFO] [1645880466.458653387]: Loaded tag config: 188, size: 0.065, frame_name: viewed_tag_188
# [ INFO] [1645880466.458675322]: Loaded tag config: 189, size: 0.065, frame_name: viewed_tag_189
# [ INFO] [1645880466.458710000]: Loaded tag config: 190, size: 0.065, frame_name: viewed_tag_190
# [ INFO] [1645880466.458732449]: Loaded tag config: 191, size: 0.065, frame_name: viewed_tag_191
# [ INFO] [1645880466.458761248]: Loaded tag config: 192, size: 0.065, frame_name: viewed_tag_192
# [ INFO] [1645880466.458786848]: Loaded tag config: 193, size: 0.065, frame_name: viewed_tag_193
# [ INFO] [1645880466.458812616]: Loaded tag config: 194, size: 0.065, frame_name: viewed_tag_194
# [ INFO] [1645880466.458833979]: Loaded tag config: 195, size: 0.065, frame_name: viewed_tag_195
# [ INFO] [1645880466.458856442]: Loaded tag config: 196, size: 0.065, frame_name: viewed_tag_196
# [ INFO] [1645880466.458878839]: Loaded tag config: 197, size: 0.065, frame_name: viewed_tag_197
# [ INFO] [1645880466.458922709]: Loaded tag config: 198, size: 0.065, frame_name: viewed_tag_198
# [ INFO] [1645880466.458946050]: Loaded tag config: 199, size: 0.065, frame_name: viewed_tag_199
# [ INFO] [1645880466.458967981]: Loaded tag config: 200, size: 0.065, frame_name: viewed_tag_200
# the rosdep view is empty: call 'sudo rosdep init' and 'rosdep update'
# [Testcase: testapriltags_tester_node] ... ok
#
# [ROSTEST]-----------------------------------------------------------------------
#
# [apriltags_ros_test.rosunit-apriltags_tester_node/test_publisher_and_subscriber][passed]
# [apriltags_ros_test.rosunit-apriltags_tester_node/test_with_known_image][passed]
#
# SUMMARY
#  * RESULT: SUCCESS
#  * TESTS: 2
#  * ERRORS: 0
#  * FAILURES: 0
#
# rostest log file is in /root/.ros/log/rostest-166ed9e33119-9016.log
